# %% [markdown]
# # Environment: Google Colab

# %% [markdown]
# # Phase 1: Image Assessment and Metrics Analysis

# %%
import cv2
import numpy as np
import os
import glob

def image_assessment(image_path):
    """
      Analyses an image to determine the correct processing path
      Returns a dictionary containing the decision, reason, and raw metrics
    """
    img = cv2.imread(image_path)
    if img is None:
        return {"decision": "Error", "reason": "Image not found", "metrics": {}}

    # 1. Convert to grayscale for analysis
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

    # 2. Calculate Metrics

    # A. Brightness (average pixel intensity)
    # Range: 0 (pure black) - 255 (pure white)
    avg_brightness = np.mean(gray)

    # B. Glare (saturation check)
    # Count pixels that are 'blown out' (pure white > 250)
    # Calculate the ratio of these pixels to the total image size
    num_white_pixels = np.sum(gray > 250)
    total_pixels = gray.size
    glare_ratio = num_white_pixels / total_pixels

    # C. Blur (Laplacian variance)
    # High variance = Sharp edges, Low variance = Blurry
    # Note: Glare can artificially spike this score, which is why we check glare first.
    laplacian_var = cv2.Laplacian(gray, cv2.CV_64F).var()

    # 3. Decision Logic (Based on calibration)

    # Dark check
    # Catch pitch black/dark images
    if avg_brightness < 40:
        return {"decision": "PATH_B_LOW_LIGHT", "reason": f"Too Dark ({avg_brightness:.1f})"}

    # Glare/Overexposure check
    # Very high Laplacian variance often means harsh edges caused by glare
    # Values chosen empirically from dataset observations
    elif laplacian_var > 2400:
        return {"decision": "PATH_B_GLARE", "reason": f"Extreme Contrast/Glare ({laplacian_var:.0f})"}

    # Night glare backup
    # For night images that aren't super sharp but have bright spots like headlights
    # I restrict this to avg_brightness < 60 to avoids misclassifying daytime sky or windows as glare
    elif glare_ratio > 0.005 and avg_brightness < 60:
        return {"decision": "PATH_B_GLARE", "reason": f"Night Spots ({glare_ratio:.4f})"}

    # Blur check
    # Catch blurry/fuzzy images
    elif laplacian_var < 180:
        return {"decision": "PATH_B_DEBLUR", "reason": f"Blurry ({laplacian_var:.0f})"}

    # Standard path
    else:
        return {"decision": "PATH_A_STANDARD", "reason": "Clean Image"}

    # return {
    #     "decision": decision,
    #     "reason": reason,
    #     "metrics": {
    #         "brightness": avg_brightness,
    #         "glare": glare_ratio,
    #         "blur": laplacian_var
    #     }
    # }

# %%
def test_folder(folder_path):
    print(f"\n--- Testing: {os.path.basename(folder_path)} ---")
    files = glob.glob(os.path.join(folder_path, "*.*"))
    for f in files:
        if not f.lower().endswith(('.jpg', '.png', '.jpeg')):
          continue
        res = image_assessment(f)

        print(f"{os.path.basename(f):<10} -> {res['decision']:<20} | {res['reason']}")

# Hand picked subset from AOLP to calibrate the values
clear_folder_path = '/content/drive/MyDrive/FYP_Stage1_Test/Easy_Clear'
bad_folder_path = '/content/drive/MyDrive/FYP_Stage1_Test/Hard_Blurry'

## Uncomment this and run this cell for output
test_folder(clear_folder_path)
test_folder(bad_folder_path)
# Out:
# --- Testing: Easy_Clear ---
# 139.jpg    -> PATH_A_STANDARD      | Clean Image
# 143.jpg    -> PATH_A_STANDARD      | Clean Image
# 142.jpg    -> PATH_A_STANDARD      | Clean Image
# 138.jpg    -> PATH_A_STANDARD      | Clean Image
# 137.jpg    -> PATH_A_STANDARD      | Clean Image
# 410.jpg    -> PATH_A_STANDARD      | Clean Image
# 406.jpg    -> PATH_A_STANDARD      | Clean Image
# 407.jpg    -> PATH_A_STANDARD      | Clean Image
# 409.jpg    -> PATH_A_STANDARD      | Clean Image
# 408.jpg    -> PATH_A_STANDARD      | Clean Image
# 329.jpg    -> PATH_A_STANDARD      | Clean Image
# 330.jpg    -> PATH_A_STANDARD      | Clean Image
# 328.jpg    -> PATH_A_STANDARD      | Clean Image
# 331.jpg    -> PATH_A_STANDARD      | Clean Image
# 334.jpg    -> PATH_A_STANDARD      | Clean Image
# 332.jpg    -> PATH_A_STANDARD      | Clean Image
# 338.jpg    -> PATH_A_STANDARD      | Clean Image
# 336.jpg    -> PATH_A_STANDARD      | Clean Image
# 335.jpg    -> PATH_A_STANDARD      | Clean Image
# 337.jpg    -> PATH_A_STANDARD      | Clean Image
# 584.jpg    -> PATH_A_STANDARD      | Clean Image
# 582.jpg    -> PATH_A_STANDARD      | Clean Image
# 583.jpg    -> PATH_A_STANDARD      | Clean Image
# 585.jpg    -> PATH_A_STANDARD      | Clean Image
# 581.jpg    -> PATH_A_STANDARD      | Clean Image
# 610.jpg    -> PATH_A_STANDARD      | Clean Image
# 613.jpg    -> PATH_A_STANDARD      | Clean Image
# 614.jpg    -> PATH_A_STANDARD      | Clean Image
# 615.jpg    -> PATH_A_STANDARD      | Clean Image
# 612.jpg    -> PATH_A_STANDARD      | Clean Image
#
# --- Testing: Hard_Blurry ---
# 403.jpg    -> PATH_B_LOW_LIGHT     | Too Dark (24.1)
# 655.jpg    -> PATH_B_GLARE         | Extreme Contrast/Glare (2627)
# 663.jpg    -> PATH_B_GLARE         | Extreme Contrast/Glare (3066)
# 649.jpg    -> PATH_B_GLARE         | Extreme Contrast/Glare (2804)
# 644.jpg    -> PATH_B_GLARE         | Extreme Contrast/Glare (2955)
# 646.jpg    -> PATH_B_GLARE         | Extreme Contrast/Glare (3364)
# 638.jpg    -> PATH_B_GLARE         | Extreme Contrast/Glare (2915)
# 613.jpg    -> PATH_B_GLARE         | Extreme Contrast/Glare (2917)
# 612.jpg    -> PATH_B_GLARE         | Extreme Contrast/Glare (2742)
# 747.jpg    -> PATH_B_GLARE         | Extreme Contrast/Glare (2841)
# 746.jpg    -> PATH_B_GLARE         | Extreme Contrast/Glare (2785)
# 326.jpg    -> PATH_B_LOW_LIGHT     | Too Dark (26.5)
# 323.jpg    -> PATH_B_LOW_LIGHT     | Too Dark (11.7)
# 464.jpg    -> PATH_B_LOW_LIGHT     | Too Dark (20.3)
# 463.jpg    -> PATH_B_LOW_LIGHT     | Too Dark (11.9)
# 83.jpg     -> PATH_A_STANDARD      | Clean Image
# 51.jpg     -> PATH_A_STANDARD      | Clean Image
# 128.jpg    -> PATH_A_STANDARD      | Clean Image
# 97.jpg     -> PATH_A_STANDARD      | Clean Image
# 11.jpg     -> PATH_A_STANDARD      | Clean Image
# 124.jpg    -> PATH_A_STANDARD      | Clean Image
# 122.jpg    -> PATH_A_STANDARD      | Clean Image
# 139.jpg    -> PATH_A_STANDARD      | Clean Image
# 277.jpg    -> PATH_A_STANDARD      | Clean Image
# 292.jpg    -> PATH_A_STANDARD      | Clean Image
# 304.jpg    -> PATH_A_STANDARD      | Clean Image
# 140.jpg    -> PATH_B_LOW_LIGHT     | Too Dark (31.2)
# 141.jpg    -> PATH_B_LOW_LIGHT     | Too Dark (18.7)
# 103.jpg    -> PATH_B_LOW_LIGHT     | Too Dark (8.6)
# 133.jpg    -> PATH_B_LOW_LIGHT     | Too Dark (13.6)

# %% [markdown]
# # Phase 2: Preprocessing and Enhancement

# %%
import cv2
import numpy as np

# Stream A and B1 (lightweight logic)

def stream_a_standard(image):
    """
      Path A: Minimal processing for already good images
    """
    # 1. Convert to Grayscale (Required for OCR later)
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

    # 2. Light Gaussian Blur (Removes camera sensor noise)
    # Kernel size (3,3) is gentle so no losing edge definition

    # Why blurring the grayscale instead of BGR:
    # 1. Cleaner blur: Grayscale avoid colour smear so can have cleaner edges
    # 2. Faster computing: Blurring a grayscale process 1 channel only
    # 3. Consistent input: Match the processing stream for CLAHE
    processed = cv2.GaussianBlur(gray, (3, 3), 0)

    # 3. Convert back to BGR
    processed_bgr = cv2.cvtColor(processed, cv2.COLOR_GRAY2BGR)

    return processed_bgr

def stream_b1_illumination(image):
    """
      - Path B1: Fix glare/low light using CLAHE for images that are too dark or have bright headlight spots
      - CLAHE operates on small tiles (grid size 8x8). It boosts details in dark areas (low light) and limits
        contrast amplification in bright spots (glare), making it effective for both conditions
    """
    # 1. Convert to Grayscale
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

    # 2. Apply CLAHE
    # clipLimit=2.0 prevents noise amplification in flat areas.
    clahe = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(8,8))
    enhanced = clahe.apply(gray)

    # 3. Convert back to BGR for consistency
    enhanced_bgr = cv2.cvtColor(enhanced, cv2.COLOR_GRAY2BGR)

    return enhanced_bgr

# %%
# Clone Restormer
# !git clone https://github.com/swz30/Restormer.git
# %cd Restormer
# !wget https://github.com/swz30/Restormer/releases/download/v1.0/motion_deblurring.pth -P Motion_Deblurring/pretrained_models
# Out:
# Cloning into 'Restormer'...
# remote: Enumerating objects: 312, done.
# remote: Counting objects: 100% (115/115), done.
# remote: Compressing objects: 100% (43/43), done.
# remote: Total 312 (delta 74), reused 72 (delta 72), pack-reused 197 (from 2)
# Receiving objects: 100% (312/312), 1.55 MiB | 29.34 MiB/s, done.
# Resolving deltas: 100% (131/131), done.
# /content/Restormer
# --2025-12-26 15:20:13--  https://github.com/swz30/Restormer/releases/download/v1.0/motion_deblurring.pth
# Resolving github.com (github.com)... 20.205.243.166
# Connecting to github.com (github.com)|20.205.243.166|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://release-assets.githubusercontent.com/github-production-release-asset/418793252/55c7bcd2-cb39-4d8a-adc4-acf6f6131c27?sp=r&sv=2018-11-09&sr=b&spr=https&se=2025-12-26T16%3A17%3A16Z&rscd=attachment%3B+filename%3Dmotion_deblurring.pth&rsct=application%2Foctet-stream&skoid=96c2d410-5711-43a1-aedd-ab1947aa7ab0&sktid=398a6654-997b-47e9-b12b-9515b896b4de&skt=2025-12-26T15%3A16%3A25Z&ske=2025-12-26T16%3A17%3A16Z&sks=b&skv=2018-11-09&sig=lU%2FwlfhlN3v6JJ%2FT%2FUG3TzGrqxkb2Aje1z4S3CqStWs%3D&jwt=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJpc3MiOiJnaXRodWIuY29tIiwiYXVkIjoicmVsZWFzZS1hc3NldHMuZ2l0aHVidXNlcmNvbnRlbnQuY29tIiwia2V5Ijoia2V5MSIsImV4cCI6MTc2Njc2NDIxMywibmJmIjoxNzY2NzYyNDEzLCJwYXRoIjoicmVsZWFzZWFzc2V0cHJvZHVjdGlvbi5ibG9iLmNvcmUud2luZG93cy5uZXQifQ.6OhQDCSxyhHqxoAAxI7wn2gBKHklmjxv9gne39dyFyU&response-content-disposition=attachment%3B%20filename%3Dmotion_deblurring.pth&response-content-type=application%2Foctet-stream [following]
# --2025-12-26 15:20:14--  https://release-assets.githubusercontent.com/github-production-release-asset/418793252/55c7bcd2-cb39-4d8a-adc4-acf6f6131c27?sp=r&sv=2018-11-09&sr=b&spr=https&se=2025-12-26T16%3A17%3A16Z&rscd=attachment%3B+filename%3Dmotion_deblurring.pth&rsct=application%2Foctet-stream&skoid=96c2d410-5711-43a1-aedd-ab1947aa7ab0&sktid=398a6654-997b-47e9-b12b-9515b896b4de&skt=2025-12-26T15%3A16%3A25Z&ske=2025-12-26T16%3A17%3A16Z&sks=b&skv=2018-11-09&sig=lU%2FwlfhlN3v6JJ%2FT%2FUG3TzGrqxkb2Aje1z4S3CqStWs%3D&jwt=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJpc3MiOiJnaXRodWIuY29tIiwiYXVkIjoicmVsZWFzZS1hc3NldHMuZ2l0aHVidXNlcmNvbnRlbnQuY29tIiwia2V5Ijoia2V5MSIsImV4cCI6MTc2Njc2NDIxMywibmJmIjoxNzY2NzYyNDEzLCJwYXRoIjoicmVsZWFzZWFzc2V0cHJvZHVjdGlvbi5ibG9iLmNvcmUud2luZG93cy5uZXQifQ.6OhQDCSxyhHqxoAAxI7wn2gBKHklmjxv9gne39dyFyU&response-content-disposition=attachment%3B%20filename%3Dmotion_deblurring.pth&response-content-type=application%2Foctet-stream
# Resolving release-assets.githubusercontent.com (release-assets.githubusercontent.com)... 185.199.109.133, 185.199.108.133, 185.199.111.133, ...
# Connecting to release-assets.githubusercontent.com (release-assets.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 104700429 (100M) [application/octet-stream]
# Saving to: ‘Motion_Deblurring/pretrained_models/motion_deblurring.pth’
#
# motion_deblurring.p 100%[===================>]  99.85M  10.8MB/s    in 15s
#
# 2025-12-26 15:20:29 (6.75 MB/s) - ‘Motion_Deblurring/pretrained_models/motion_deblurring.pth’ saved [104700429/104700429]

# %%
from runpy import run_path
import torch
import torch.nn.functional as F

# Stream B2 (Restormer Setup)

def load_restormer():
    """
      Loads the Restormer model into GPU memory.
    """
    # Define hyperparameters
    parameters = {
      'inp_channels':3,
      'out_channels':3,
      'dim':48,
      'num_blocks':[4,6,6,8],
      'num_refinement_blocks':4,
      'heads':[1,2,4,8],
      'ffn_expansion_factor':2.66,
      'bias':False,
      'LayerNorm_type':'WithBias',
      'dual_pixel_task':False
    }

    weights_path = 'Motion_Deblurring/pretrained_models/motion_deblurring.pth'

    # Load Architecture dynamically
    # Use run_path because Restormer is not a pip package
    restormer_arch = run_path(os.path.join('basicsr', 'models', 'archs', 'restormer_arch.py'))
    model = restormer_arch['Restormer'](**parameters)

    # Load state dict
    model.cuda()
    checkpoint = torch.load(weights_path)
    model.load_state_dict(checkpoint['params'])
    model.eval()

    return model

def stream_b2_deblur(image, model):
    """
      - Path B2: Removes motion blur using Restormer
      - Input: BGR image
      - Output: Deblurred BGR Image
    """
    # 1. Preprocessing: BGR > RGB > Tensor
    img = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    input_ = torch.from_numpy(img).float().div(255.).permute(2,0,1).unsqueeze(0).cuda()

    # 2. Padding (Restormer requires dimensions to be multiply of 8)
    h, w = input_.shape[2], input_.shape[3]
    H, W = ((h + 8) // 8) * 8, ((w + 8) // 8) * 8
    padh = H - h if h % 8 != 0 else 0
    padw = W - w if w % 8 != 0 else 0
    input_ = F.pad(input_, (0, padw, 0, padh), 'reflect')

    # 3. Inference (disable gradient tracking in PyTorch since inference only, save gpu run time)
    with torch.no_grad():
      restored = model(input_)

    # 4. Post-processing: Unpad > Clamp > Back to BGR
    restored = torch.clamp(restored, 0, 1)
    restored = restored[:, :, :h, :w] # Crop padding
    restored = restored.permute(0, 2, 3, 1).cpu().detach().numpy()
    restored = cv2.cvtColor((restored[0] * 255).astype(np.uint8), cv2.COLOR_RGB2BGR)

    return restored

# %%
import os
import glob

# Preprocess Pipeline

def preprocess_pipeline(image_path, model, output_base_folder):
  """
    The Brain of the System:
    1. Triages the image (Phase 1).
    2. Routes it to the correct Enhancement Stream (Phase 2).
    3. Saves the result.
  """
  # 1. Run image assessment (Phase 1)
  analysis = image_assessment(image_path)
  decision = analysis["decision"]
  reason = analysis["reason"]

  img = cv2.imread(image_path)
  if img is None:
    return "Error loading image"

  # 2. Route to the correct Stream (Phase 2)

  if decision == "PATH_A_STANDARD":
    # Stream A: Lightweight
    processed_img = stream_a_standard(img)
    method_tag = "Standard"

  elif decision == "PATH_B_GLARE" or decision == "PATH_B_LOW_LIGHT":
    # Stream B1: CLAHE
    processed_img = stream_b1_illumination(img)
    method_tag = "CLAHE"

  elif decision == "PATH_B_DEBLUR":
    # Stream B2: Restormer
    processed_img = stream_b2_deblur(img, model)
    method_tag = "Restormer"

  save_folder = output_base_folder
  if not os.path.exists(save_folder):
    os.makedirs(save_folder)

  filename = os.path.basename(image_path)
  save_path = os.path.join(save_folder, filename)
  cv2.imwrite(save_path, processed_img)

  return f"[{method_tag}] {reason}"

def run_system_test(input_folder, model):
  print(f"Running on: {input_folder}")

  base_output_dir = '/content/drive/MyDrive/Phase2_Results'
  folder_name = os.path.basename(os.path.dirname(input_folder))
  dataset_output_dir = os.path.join(base_output_dir, folder_name)

  files = glob.glob(os.path.join(input_folder, "*.*"))
  count = 0

  for f in files:
    if not f.lower().endswith(('.jpg', '.png', '.jpeg')):
      continue

    log_msg = preprocess_pipeline(f, model, dataset_output_dir)

    print(f"Processed: {os.path.basename(f)} -> {log_msg}")
    count += 1

  print(f"\nDone, processed {count} images.")
  print(f"Output: {dataset_output_dir}")


if 'deblur_model' not in locals():
  deblur_model = load_restormer()

image_folders = [
  '/content/drive/MyDrive/AOLP_Dataset/Subset_AC/Image',
  '/content/drive/MyDrive/AOLP_Dataset/Subset_LE/Image',
  '/content/drive/MyDrive/AOLP_Dataset/Subset_RP/Image'
]

for folder in image_folders:
  run_system_test(folder, deblur_model)
# Out:
# Running on: /content/drive/MyDrive/AOLP_Dataset/Subset_AC/Image
# Processed: 632.jpg -> [CLAHE] Extreme Contrast/Glare (2627)
# Processed: 636.jpg -> [CLAHE] Extreme Contrast/Glare (2893)
# Processed: 635.jpg -> [CLAHE] Extreme Contrast/Glare (2860)
# Processed: 668.jpg -> [CLAHE] Extreme Contrast/Glare (3091)
# Processed: 648.jpg -> [CLAHE] Extreme Contrast/Glare (3022)
# Processed: 680.jpg -> [CLAHE] Extreme Contrast/Glare (2870)
# Processed: 639.jpg -> [CLAHE] Extreme Contrast/Glare (2658)
# Processed: 656.jpg -> [CLAHE] Extreme Contrast/Glare (3028)
# Processed: 637.jpg -> [CLAHE] Extreme Contrast/Glare (2957)
# Processed: 647.jpg -> [CLAHE] Extreme Contrast/Glare (2977)
# Processed: 643.jpg -> [CLAHE] Extreme Contrast/Glare (2976)
# Processed: 675.jpg -> [CLAHE] Extreme Contrast/Glare (2734)
# Processed: 669.jpg -> [CLAHE] Extreme Contrast/Glare (2745)
# Processed: 642.jpg -> [CLAHE] Extreme Contrast/Glare (2953)
# Processed: 651.jpg -> [CLAHE] Extreme Contrast/Glare (2699)
# Processed: 649.jpg -> [CLAHE] Extreme Contrast/Glare (2804)
# Processed: 640.jpg -> [CLAHE] Extreme Contrast/Glare (2680)
# Processed: 673.jpg -> [CLAHE] Extreme Contrast/Glare (2959)
# Processed: 630.jpg -> [CLAHE] Extreme Contrast/Glare (2857)
# Processed: 646.jpg -> [CLAHE] Extreme Contrast/Glare (2878)
# Processed: 654.jpg -> [CLAHE] Extreme Contrast/Glare (2757)
# Processed: 633.jpg -> [CLAHE] Extreme Contrast/Glare (2681)
# Processed: 674.jpg -> [CLAHE] Extreme Contrast/Glare (2938)
# Processed: 671.jpg -> [CLAHE] Extreme Contrast/Glare (2668)
# Processed: 658.jpg -> [CLAHE] Extreme Contrast/Glare (2950)
# Processed: 681.jpg -> [CLAHE] Extreme Contrast/Glare (2842)
# Processed: 665.jpg -> [CLAHE] Extreme Contrast/Glare (2700)
# Processed: 670.jpg -> [CLAHE] Extreme Contrast/Glare (2899)
# Processed: 634.jpg -> [CLAHE] Too Dark (31.8)
# Processed: 661.jpg -> [CLAHE] Extreme Contrast/Glare (2984)
# Processed: 644.jpg -> [CLAHE] Extreme Contrast/Glare (2955)
# Processed: 655.jpg -> [CLAHE] Extreme Contrast/Glare (2627)
# Processed: 679.jpg -> [CLAHE] Extreme Contrast/Glare (2968)
# Processed: 653.jpg -> [CLAHE] Extreme Contrast/Glare (3164)
# Processed: 641.jpg -> [CLAHE] Extreme Contrast/Glare (2758)
# Processed: 676.jpg -> [CLAHE] Extreme Contrast/Glare (2942)
# Processed: 660.jpg -> [CLAHE] Extreme Contrast/Glare (2705)
# Processed: 667.jpg -> [CLAHE] Extreme Contrast/Glare (2834)
# Processed: 666.jpg -> [CLAHE] Extreme Contrast/Glare (2636)
# Processed: 645.jpg -> [CLAHE] Extreme Contrast/Glare (3179)
# Processed: 657.jpg -> [CLAHE] Extreme Contrast/Glare (3115)
# Processed: 672.jpg -> [CLAHE] Extreme Contrast/Glare (2831)
# Processed: 652.jpg -> [CLAHE] Extreme Contrast/Glare (2843)
# Processed: 663.jpg -> [CLAHE] Extreme Contrast/Glare (3066)
# Processed: 638.jpg -> [CLAHE] Extreme Contrast/Glare (2788)
# Processed: 664.jpg -> [CLAHE] Extreme Contrast/Glare (2880)
# Processed: 659.jpg -> [CLAHE] Extreme Contrast/Glare (2785)
# Processed: 678.jpg -> [CLAHE] Extreme Contrast/Glare (2957)
# Processed: 662.jpg -> [CLAHE] Extreme Contrast/Glare (2795)
# Processed: 650.jpg -> [CLAHE] Extreme Contrast/Glare (2937)
# Processed: 677.jpg -> [CLAHE] Extreme Contrast/Glare (2918)
# Processed: 631.jpg -> [CLAHE] Extreme Contrast/Glare (2687)
# Processed: 321.jpg -> [Standard] Clean Image
# Processed: 328.jpg -> [Standard] Clean Image
# Processed: 323.jpg -> [CLAHE] Too Dark (11.7)
# Processed: 333.jpg -> [Standard] Clean Image
# Processed: 343.jpg -> [Standard] Clean Image
# Processed: 318.jpg -> [Standard] Clean Image
# Processed: 353.jpg -> [Standard] Clean Image
# Processed: 325.jpg -> [CLAHE] Too Dark (40.0)
# Processed: 360.jpg -> [Standard] Clean Image
# Processed: 312.jpg -> [Standard] Clean Image
# Processed: 311.jpg -> [Standard] Clean Image
# Processed: 335.jpg -> [Standard] Clean Image
# Processed: 340.jpg -> [Standard] Clean Image
# Processed: 317.jpg -> [Standard] Clean Image
# Processed: 357.jpg -> [Standard] Clean Image
# Processed: 314.jpg -> [CLAHE] Extreme Contrast/Glare (2492)
# Processed: 337.jpg -> [Standard] Clean Image
# Processed: 336.jpg -> [Standard] Clean Image
# Processed: 322.jpg -> [Standard] Clean Image
# Processed: 329.jpg -> [Standard] Clean Image
# Processed: 346.jpg -> [Standard] Clean Image
# Processed: 326.jpg -> [CLAHE] Too Dark (26.5)
# Processed: 313.jpg -> [Standard] Clean Image
# Processed: 330.jpg -> [Standard] Clean Image
# Processed: 354.jpg -> [Standard] Clean Image
# Processed: 308.jpg -> [Standard] Clean Image
# Processed: 309.jpg -> [Standard] Clean Image
# Processed: 332.jpg -> [Standard] Clean Image
# Processed: 319.jpg -> [Standard] Clean Image
# Processed: 324.jpg -> [CLAHE] Too Dark (22.9)
# Processed: 356.jpg -> [Standard] Clean Image
# Processed: 349.jpg -> [Standard] Clean Image
# Processed: 359.jpg -> [Standard] Clean Image
# Processed: 334.jpg -> [Standard] Clean Image
# Processed: 342.jpg -> [Standard] Clean Image
# Processed: 361.jpg -> [Standard] Clean Image
# Processed: 320.jpg -> [Standard] Clean Image
# Processed: 351.jpg -> [Standard] Clean Image
# Processed: 315.jpg -> [Standard] Clean Image
# Processed: 341.jpg -> [Standard] Clean Image
# Processed: 345.jpg -> [Standard] Clean Image
# Processed: 338.jpg -> [Standard] Clean Image
# Processed: 310.jpg -> [Standard] Clean Image
# Processed: 327.jpg -> [Standard] Clean Image
# Processed: 339.jpg -> [Standard] Clean Image
# Processed: 348.jpg -> [Standard] Clean Image
# Processed: 362.jpg -> [Standard] Clean Image
# Processed: 331.jpg -> [Standard] Clean Image
# Processed: 355.jpg -> [Standard] Clean Image
# Processed: 352.jpg -> [CLAHE] Night Spots (0.0074)
# Processed: 358.jpg -> [Standard] Clean Image
# Processed: 316.jpg -> [Standard] Clean Image
# Processed: 344.jpg -> [Standard] Clean Image
# Processed: 350.jpg -> [Standard] Clean Image
# Processed: 347.jpg -> [Standard] Clean Image
# Processed: 363.jpg -> [Standard] Clean Image
# Processed: 417.jpg -> [Standard] Clean Image
# Processed: 402.jpg -> [Standard] Clean Image
# Processed: 421.jpg -> [Standard] Clean Image
# Processed: 379.jpg -> [Standard] Clean Image
# Processed: 399.jpg -> [Standard] Clean Image
# Processed: 424.jpg -> [Standard] Clean Image
# Processed: 387.jpg -> [Standard] Clean Image
# Processed: 374.jpg -> [Standard] Clean Image
# Processed: 393.jpg -> [Standard] Clean Image
# Processed: 383.jpg -> [Standard] Clean Image
# Processed: 423.jpg -> [Standard] Clean Image
# Processed: 414.jpg -> [Standard] Clean Image
# Processed: 376.jpg -> [Standard] Clean Image
# Processed: 426.jpg -> [Standard] Clean Image
# Processed: 420.jpg -> [Standard] Clean Image
# Processed: 385.jpg -> [Standard] Clean Image
# Processed: 397.jpg -> [Standard] Clean Image
# Processed: 378.jpg -> [Standard] Clean Image
# Processed: 404.jpg -> [Standard] Clean Image
# Processed: 380.jpg -> [Standard] Clean Image
# Processed: 372.jpg -> [Standard] Clean Image
# Processed: 368.jpg -> [Standard] Clean Image
# Processed: 419.jpg -> [Standard] Clean Image
# Processed: 401.jpg -> [Standard] Clean Image
# Processed: 418.jpg -> [CLAHE] Extreme Contrast/Glare (2419)
# Processed: 425.jpg -> [Standard] Clean Image
# Processed: 409.jpg -> [CLAHE] Extreme Contrast/Glare (2904)
# Processed: 388.jpg -> [Standard] Clean Image
# Processed: 411.jpg -> [Standard] Clean Image
# Processed: 405.jpg -> [Standard] Clean Image
# Processed: 413.jpg -> [Standard] Clean Image
# Processed: 366.jpg -> [Standard] Clean Image
# Processed: 381.jpg -> [Standard] Clean Image
# Processed: 395.jpg -> [Standard] Clean Image
# Processed: 406.jpg -> [Standard] Clean Image
# Processed: 382.jpg -> [Standard] Clean Image
# Processed: 408.jpg -> [Standard] Clean Image
# Processed: 370.jpg -> [Standard] Clean Image
# Processed: 415.jpg -> [Standard] Clean Image
# Processed: 394.jpg -> [Standard] Clean Image
# Processed: 369.jpg -> [Standard] Clean Image
# Processed: 410.jpg -> [Standard] Clean Image
# Processed: 386.jpg -> [Standard] Clean Image
# Processed: 389.jpg -> [Standard] Clean Image
# Processed: 416.jpg -> [Standard] Clean Image
# Processed: 377.jpg -> [Standard] Clean Image
# Processed: 391.jpg -> [Standard] Clean Image
# Processed: 403.jpg -> [Standard] Clean Image
# Processed: 364.jpg -> [Standard] Clean Image
# Processed: 373.jpg -> [Standard] Clean Image
# Processed: 427.jpg -> [Standard] Clean Image
# Processed: 422.jpg -> [Standard] Clean Image
# Processed: 375.jpg -> [Standard] Clean Image
# Processed: 400.jpg -> [Standard] Clean Image
# Processed: 412.jpg -> [Standard] Clean Image
# Processed: 390.jpg -> [Standard] Clean Image
# Processed: 371.jpg -> [Standard] Clean Image
# Processed: 367.jpg -> [Standard] Clean Image
# Processed: 384.jpg -> [Standard] Clean Image
# Processed: 396.jpg -> [Standard] Clean Image
# Processed: 392.jpg -> [Standard] Clean Image
# Processed: 365.jpg -> [Standard] Clean Image
# Processed: 398.jpg -> [Standard] Clean Image
# Processed: 407.jpg -> [Standard] Clean Image
# Processed: 486.jpg -> [Standard] Clean Image
# Processed: 482.jpg -> [Standard] Clean Image
# Processed: 480.jpg -> [Standard] Clean Image
# Processed: 443.jpg -> [Standard] Clean Image
# Processed: 442.jpg -> [Standard] Clean Image
# Processed: 453.jpg -> [Standard] Clean Image
# Processed: 449.jpg -> [Standard] Clean Image
# Processed: 434.jpg -> [Standard] Clean Image
# Processed: 476.jpg -> [Standard] Clean Image
# Processed: 429.jpg -> [Standard] Clean Image
# Processed: 438.jpg -> [Standard] Clean Image
# Processed: 485.jpg -> [Standard] Clean Image
# Processed: 462.jpg -> [Standard] Clean Image
# Processed: 458.jpg -> [Standard] Clean Image
# Processed: 454.jpg -> [Standard] Clean Image
# Processed: 487.jpg -> [Standard] Clean Image
# Processed: 472.jpg -> [Standard] Clean Image
# Processed: 461.jpg -> [Standard] Clean Image
# Processed: 432.jpg -> [CLAHE] Extreme Contrast/Glare (2610)
# Processed: 481.jpg -> [Standard] Clean Image
# Processed: 477.jpg -> [Standard] Clean Image
# Processed: 456.jpg -> [Standard] Clean Image
# Processed: 431.jpg -> [CLAHE] Extreme Contrast/Glare (2476)
# Processed: 460.jpg -> [Standard] Clean Image
# Processed: 440.jpg -> [Standard] Clean Image
# Processed: 474.jpg -> [Standard] Clean Image
# Processed: 435.jpg -> [Standard] Clean Image
# Processed: 447.jpg -> [Standard] Clean Image
# Processed: 467.jpg -> [Standard] Clean Image
# Processed: 448.jpg -> [Standard] Clean Image
# Processed: 463.jpg -> [CLAHE] Too Dark (11.9)
# Processed: 441.jpg -> [Standard] Clean Image
# Processed: 470.jpg -> [Standard] Clean Image
# Processed: 466.jpg -> [Standard] Clean Image
# Processed: 471.jpg -> [Standard] Clean Image
# Processed: 479.jpg -> [Standard] Clean Image
# Processed: 468.jpg -> [Standard] Clean Image
# Processed: 445.jpg -> [Standard] Clean Image
# Processed: 464.jpg -> [CLAHE] Too Dark (20.3)
# Processed: 469.jpg -> [Standard] Clean Image
# Processed: 451.jpg -> [CLAHE] Extreme Contrast/Glare (2832)
# Processed: 459.jpg -> [Standard] Clean Image
# Processed: 430.jpg -> [Standard] Clean Image
# Processed: 439.jpg -> [Standard] Clean Image
# Processed: 446.jpg -> [CLAHE] Extreme Contrast/Glare (2537)
# Processed: 457.jpg -> [Standard] Clean Image
# Processed: 452.jpg -> [CLAHE] Extreme Contrast/Glare (3007)
# Processed: 473.jpg -> [Standard] Clean Image
# Processed: 484.jpg -> [Standard] Clean Image
# Processed: 455.jpg -> [Standard] Clean Image
# Processed: 450.jpg -> [Standard] Clean Image
# Processed: 433.jpg -> [Standard] Clean Image
# Processed: 437.jpg -> [Standard] Clean Image
# Processed: 478.jpg -> [Standard] Clean Image
# Processed: 436.jpg -> [Standard] Clean Image
# Processed: 428.jpg -> [Standard] Clean Image
# Processed: 483.jpg -> [Standard] Clean Image
# Processed: 465.jpg -> [Standard] Clean Image
# Processed: 475.jpg -> [Standard] Clean Image
# Processed: 444.jpg -> [Standard] Clean Image
# Processed: 535.jpg -> [Standard] Clean Image
# Processed: 508.jpg -> [Standard] Clean Image
# Processed: 520.jpg -> [Standard] Clean Image
# Processed: 538.jpg -> [Standard] Clean Image
# Processed: 511.jpg -> [Standard] Clean Image
# Processed: 502.jpg -> [Standard] Clean Image
# Processed: 544.jpg -> [Standard] Clean Image
# Processed: 543.jpg -> [Standard] Clean Image
# Processed: 522.jpg -> [Standard] Clean Image
# Processed: 489.jpg -> [Standard] Clean Image
# Processed: 528.jpg -> [Standard] Clean Image
# Processed: 536.jpg -> [Standard] Clean Image
# Processed: 529.jpg -> [Standard] Clean Image
# Processed: 509.jpg -> [Standard] Clean Image
# Processed: 494.jpg -> [Standard] Clean Image
# Processed: 496.jpg -> [Standard] Clean Image
# Processed: 545.jpg -> [CLAHE] Extreme Contrast/Glare (2472)
# Processed: 537.jpg -> [Standard] Clean Image
# Processed: 493.jpg -> [Standard] Clean Image
# Processed: 498.jpg -> [Standard] Clean Image
# Processed: 504.jpg -> [Standard] Clean Image
# Processed: 500.jpg -> [Standard] Clean Image
# Processed: 542.jpg -> [Standard] Clean Image
# Processed: 488.jpg -> [Standard] Clean Image
# Processed: 539.jpg -> [Standard] Clean Image
# Processed: 524.jpg -> [Standard] Clean Image
# Processed: 506.jpg -> [Standard] Clean Image
# Processed: 501.jpg -> [Standard] Clean Image
# Processed: 503.jpg -> [Standard] Clean Image
# Processed: 525.jpg -> [Standard] Clean Image
# Processed: 497.jpg -> [Standard] Clean Image
# Processed: 515.jpg -> [Standard] Clean Image
# Processed: 540.jpg -> [Standard] Clean Image
# Processed: 507.jpg -> [Standard] Clean Image
# Processed: 521.jpg -> [Standard] Clean Image
# Processed: 499.jpg -> [Standard] Clean Image
# Processed: 526.jpg -> [Standard] Clean Image
# Processed: 532.jpg -> [Standard] Clean Image
# Processed: 495.jpg -> [Standard] Clean Image
# Processed: 492.jpg -> [Standard] Clean Image
# Processed: 514.jpg -> [Standard] Clean Image
# Processed: 516.jpg -> [Standard] Clean Image
# Processed: 512.jpg -> [Standard] Clean Image
# Processed: 491.jpg -> [Standard] Clean Image
# Processed: 531.jpg -> [CLAHE] Extreme Contrast/Glare (2708)
# Processed: 518.jpg -> [Standard] Clean Image
# Processed: 490.jpg -> [Standard] Clean Image
# Processed: 517.jpg -> [Standard] Clean Image
# Processed: 533.jpg -> [Standard] Clean Image
# Processed: 534.jpg -> [Standard] Clean Image
# Processed: 505.jpg -> [Standard] Clean Image
# Processed: 527.jpg -> [Standard] Clean Image
# Processed: 513.jpg -> [Standard] Clean Image
# Processed: 546.jpg -> [Standard] Clean Image
# Processed: 523.jpg -> [Standard] Clean Image
# Processed: 510.jpg -> [Standard] Clean Image
# Processed: 541.jpg -> [Standard] Clean Image
# Processed: 530.jpg -> [Standard] Clean Image
# Processed: 519.jpg -> [Standard] Clean Image
# Processed: 556.jpg -> [Standard] Clean Image
# Processed: 588.jpg -> [Standard] Clean Image
# Processed: 553.jpg -> [Standard] Clean Image
# Processed: 563.jpg -> [Standard] Clean Image
# Processed: 564.jpg -> [Standard] Clean Image
# Processed: 568.jpg -> [Standard] Clean Image
# Processed: 547.jpg -> [Standard] Clean Image
# Processed: 549.jpg -> [Standard] Clean Image
# Processed: 592.jpg -> [Standard] Clean Image
# Processed: 579.jpg -> [Standard] Clean Image
# Processed: 581.jpg -> [Standard] Clean Image
# Processed: 572.jpg -> [Standard] Clean Image
# Processed: 567.jpg -> [Standard] Clean Image
# Processed: 551.jpg -> [Standard] Clean Image
# Processed: 550.jpg -> [Standard] Clean Image
# Processed: 587.jpg -> [Standard] Clean Image
# Processed: 608.jpg -> [Standard] Clean Image
# Processed: 598.jpg -> [Standard] Clean Image
# Processed: 552.jpg -> [Standard] Clean Image
# Processed: 606.jpg -> [Standard] Clean Image
# Processed: 604.jpg -> [Standard] Clean Image
# Processed: 595.jpg -> [Standard] Clean Image
# Processed: 583.jpg -> [Standard] Clean Image
# Processed: 603.jpg -> [Standard] Clean Image
# Processed: 602.jpg -> [Standard] Clean Image
# Processed: 566.jpg -> [Standard] Clean Image
# Processed: 599.jpg -> [Standard] Clean Image
# Processed: 561.jpg -> [Standard] Clean Image
# Processed: 590.jpg -> [Standard] Clean Image
# Processed: 570.jpg -> [CLAHE] Extreme Contrast/Glare (2420)
# Processed: 548.jpg -> [Standard] Clean Image
# Processed: 582.jpg -> [Standard] Clean Image
# Processed: 555.jpg -> [CLAHE] Extreme Contrast/Glare (2401)
# Processed: 571.jpg -> [Standard] Clean Image
# Processed: 554.jpg -> [CLAHE] Extreme Contrast/Glare (3421)
# Processed: 576.jpg -> [Standard] Clean Image
# Processed: 607.jpg -> [Standard] Clean Image
# Processed: 573.jpg -> [Standard] Clean Image
# Processed: 562.jpg -> [Standard] Clean Image
# Processed: 559.jpg -> [Standard] Clean Image
# Processed: 593.jpg -> [Standard] Clean Image
# Processed: 589.jpg -> [Standard] Clean Image
# Processed: 569.jpg -> [Standard] Clean Image
# Processed: 575.jpg -> [Standard] Clean Image
# Processed: 574.jpg -> [Standard] Clean Image
# Processed: 586.jpg -> [Standard] Clean Image
# Processed: 596.jpg -> [Standard] Clean Image
# Processed: 578.jpg -> [Standard] Clean Image
# Processed: 580.jpg -> [Standard] Clean Image
# Processed: 585.jpg -> [Standard] Clean Image
# Processed: 557.jpg -> [Standard] Clean Image
# Processed: 605.jpg -> [Standard] Clean Image
# Processed: 584.jpg -> [Standard] Clean Image
# Processed: 601.jpg -> [CLAHE] Extreme Contrast/Glare (2662)
# Processed: 597.jpg -> [Standard] Clean Image
# Processed: 565.jpg -> [Standard] Clean Image
# Processed: 577.jpg -> [Standard] Clean Image
# Processed: 594.jpg -> [Standard] Clean Image
# Processed: 560.jpg -> [Standard] Clean Image
# Processed: 600.jpg -> [Standard] Clean Image
# Processed: 558.jpg -> [Standard] Clean Image
# Processed: 591.jpg -> [Standard] Clean Image
# Processed: 624.jpg -> [Standard] Clean Image
# Processed: 612.jpg -> [Standard] Clean Image
# Processed: 610.jpg -> [Standard] Clean Image
# Processed: 623.jpg -> [Standard] Clean Image
# Processed: 611.jpg -> [Standard] Clean Image
# Processed: 609.jpg -> [Standard] Clean Image
# Processed: 615.jpg -> [Standard] Clean Image
# Processed: 618.jpg -> [Standard] Clean Image
# Processed: 613.jpg -> [Standard] Clean Image
# Processed: 628.jpg -> [Standard] Clean Image
# Processed: 626.jpg -> [Standard] Clean Image
# Processed: 614.jpg -> [Standard] Clean Image
# Processed: 629.jpg -> [Standard] Clean Image
# Processed: 622.jpg -> [Standard] Clean Image
# Processed: 616.jpg -> [Standard] Clean Image
# Processed: 625.jpg -> [Standard] Clean Image
# Processed: 617.jpg -> [Standard] Clean Image
# Processed: 627.jpg -> [Standard] Clean Image
# Processed: 620.jpg -> [Standard] Clean Image
# Processed: 621.jpg -> [Standard] Clean Image
# Processed: 619.jpg -> [Standard] Clean Image
# Processed: 29.jpg -> [Standard] Clean Image
# Processed: 1.jpg -> [Standard] Clean Image
# Processed: 30.jpg -> [Standard] Clean Image
# Processed: 4.jpg -> [Standard] Clean Image
# Processed: 74.jpg -> [Standard] Clean Image
# Processed: 85.jpg -> [Standard] Clean Image
# Processed: 41.jpg -> [Standard] Clean Image
# Processed: 36.jpg -> [Standard] Clean Image
# Processed: 66.jpg -> [Standard] Clean Image
# Processed: 45.jpg -> [Standard] Clean Image
# Processed: 72.jpg -> [Standard] Clean Image
# Processed: 62.jpg -> [Standard] Clean Image
# Processed: 44.jpg -> [Standard] Clean Image
# Processed: 50.jpg -> [Standard] Clean Image
# Processed: 31.jpg -> [Standard] Clean Image
# Processed: 42.jpg -> [Standard] Clean Image
# Processed: 80.jpg -> [Standard] Clean Image
# Processed: 58.jpg -> [Standard] Clean Image
# Processed: 83.jpg -> [Standard] Clean Image
# Processed: 37.jpg -> [Standard] Clean Image
# Processed: 52.jpg -> [Standard] Clean Image
# Processed: 55.jpg -> [Standard] Clean Image
# Processed: 82.jpg -> [Standard] Clean Image
# Processed: 57.jpg -> [Standard] Clean Image
# Processed: 86.jpg -> [Standard] Clean Image
# Processed: 38.jpg -> [Standard] Clean Image
# Processed: 65.jpg -> [Standard] Clean Image
# Processed: 71.jpg -> [Standard] Clean Image
# Processed: 61.jpg -> [Standard] Clean Image
# Processed: 6.jpg -> [Standard] Clean Image
# Processed: 59.jpg -> [Standard] Clean Image
# Processed: 73.jpg -> [Standard] Clean Image
# Processed: 33.jpg -> [Standard] Clean Image
# Processed: 34.jpg -> [Standard] Clean Image
# Processed: 70.jpg -> [Standard] Clean Image
# Processed: 64.jpg -> [Standard] Clean Image
# Processed: 54.jpg -> [Standard] Clean Image
# Processed: 63.jpg -> [Standard] Clean Image
# Processed: 76.jpg -> [Standard] Clean Image
# Processed: 67.jpg -> [Standard] Clean Image
# Processed: 84.jpg -> [Standard] Clean Image
# Processed: 68.jpg -> [Standard] Clean Image
# Processed: 35.jpg -> [Standard] Clean Image
# Processed: 39.jpg -> [Standard] Clean Image
# Processed: 69.jpg -> [Standard] Clean Image
# Processed: 56.jpg -> [Standard] Clean Image
# Processed: 7.jpg -> [Standard] Clean Image
# Processed: 53.jpg -> [Standard] Clean Image
# Processed: 47.jpg -> [Standard] Clean Image
# Processed: 81.jpg -> [Standard] Clean Image
# Processed: 75.jpg -> [Standard] Clean Image
# Processed: 32.jpg -> [Standard] Clean Image
# Processed: 78.jpg -> [Standard] Clean Image
# Processed: 79.jpg -> [Standard] Clean Image
# Processed: 48.jpg -> [Standard] Clean Image
# Processed: 5.jpg -> [Standard] Clean Image
# Processed: 43.jpg -> [Standard] Clean Image
# Processed: 51.jpg -> [Standard] Clean Image
# Processed: 60.jpg -> [Standard] Clean Image
# Processed: 46.jpg -> [Standard] Clean Image
# Processed: 77.jpg -> [Standard] Clean Image
# Processed: 40.jpg -> [Standard] Clean Image
# Processed: 49.jpg -> [Standard] Clean Image
# Processed: 118.jpg -> [Standard] Clean Image
# Processed: 128.jpg -> [Standard] Clean Image
# Processed: 123.jpg -> [Standard] Clean Image
# Processed: 94.jpg -> [Standard] Clean Image
# Processed: 126.jpg -> [Standard] Clean Image
# Processed: 13.jpg -> [Standard] Clean Image
# Processed: 134.jpg -> [Standard] Clean Image
# Processed: 96.jpg -> [Standard] Clean Image
# Processed: 115.jpg -> [Standard] Clean Image
# Processed: 90.jpg -> [Standard] Clean Image
# Processed: 114.jpg -> [Standard] Clean Image
# Processed: 104.jpg -> [Standard] Clean Image
# Processed: 109.jpg -> [Standard] Clean Image
# Processed: 119.jpg -> [Standard] Clean Image
# Processed: 2.jpg -> [Standard] Clean Image
# Processed: 121.jpg -> [Standard] Clean Image
# Processed: 100.jpg -> [Standard] Clean Image
# Processed: 98.jpg -> [Standard] Clean Image
# Processed: 87.jpg -> [Standard] Clean Image
# Processed: 108.jpg -> [Standard] Clean Image
# Processed: 137.jpg -> [Standard] Clean Image
# Processed: 111.jpg -> [Standard] Clean Image
# Processed: 124.jpg -> [Standard] Clean Image
# Processed: 127.jpg -> [Standard] Clean Image
# Processed: 101.jpg -> [Standard] Clean Image
# Processed: 125.jpg -> [Standard] Clean Image
# Processed: 105.jpg -> [Standard] Clean Image
# Processed: 131.jpg -> [Standard] Clean Image
# Processed: 135.jpg -> [Standard] Clean Image
# Processed: 12.jpg -> [Standard] Clean Image
# Processed: 89.jpg -> [Standard] Clean Image
# Processed: 103.jpg -> [Standard] Clean Image
# Processed: 116.jpg -> [Standard] Clean Image
# Processed: 93.jpg -> [Standard] Clean Image
# Processed: 110.jpg -> [Standard] Clean Image
# Processed: 92.jpg -> [Standard] Clean Image
# Processed: 107.jpg -> [Standard] Clean Image
# Processed: 129.jpg -> [Standard] Clean Image
# Processed: 9.jpg -> [Standard] Clean Image
# Processed: 133.jpg -> [Standard] Clean Image
# Processed: 11.jpg -> [Standard] Clean Image
# Processed: 138.jpg -> [Standard] Clean Image
# Processed: 102.jpg -> [Standard] Clean Image
# Processed: 106.jpg -> [Standard] Clean Image
# Processed: 95.jpg -> [Standard] Clean Image
# Processed: 122.jpg -> [Standard] Clean Image
# Processed: 120.jpg -> [Standard] Clean Image
# Processed: 113.jpg -> [Standard] Clean Image
# Processed: 112.jpg -> [Standard] Clean Image
# Processed: 132.jpg -> [Standard] Clean Image
# Processed: 130.jpg -> [Standard] Clean Image
# Processed: 8.jpg -> [Standard] Clean Image
# Processed: 88.jpg -> [Standard] Clean Image
# Processed: 91.jpg -> [Standard] Clean Image
# Processed: 10.jpg -> [Standard] Clean Image
# Processed: 99.jpg -> [Standard] Clean Image
# Processed: 117.jpg -> [Standard] Clean Image
# Processed: 97.jpg -> [Standard] Clean Image
# Processed: 136.jpg -> [Standard] Clean Image
# Processed: 141.jpg -> [Standard] Clean Image
# Processed: 168.jpg -> [Standard] Clean Image
# Processed: 165.jpg -> [Standard] Clean Image
# Processed: 14.jpg -> [Standard] Clean Image
# Processed: 161.jpg -> [Standard] Clean Image
# Processed: 143.jpg -> [Standard] Clean Image
# Processed: 140.jpg -> [Standard] Clean Image
# Processed: 159.jpg -> [Standard] Clean Image
# Processed: 170.jpg -> [Standard] Clean Image
# Processed: 142.jpg -> [Standard] Clean Image
# Processed: 158.jpg -> [Standard] Clean Image
# Processed: 153.jpg -> [Standard] Clean Image
# Processed: 155.jpg -> [Standard] Clean Image
# Processed: 182.jpg -> [Standard] Clean Image
# Processed: 175.jpg -> [Standard] Clean Image
# Processed: 177.jpg -> [Standard] Clean Image
# Processed: 152.jpg -> [Standard] Clean Image
# Processed: 163.jpg -> [Standard] Clean Image
# Processed: 156.jpg -> [Standard] Clean Image
# Processed: 160.jpg -> [Standard] Clean Image
# Processed: 172.jpg -> [Standard] Clean Image
# Processed: 167.jpg -> [Standard] Clean Image
# Processed: 147.jpg -> [Standard] Clean Image
# Processed: 173.jpg -> [Standard] Clean Image
# Processed: 181.jpg -> [Standard] Clean Image
# Processed: 157.jpg -> [Standard] Clean Image
# Processed: 148.jpg -> [Standard] Clean Image
# Processed: 16.jpg -> [Standard] Clean Image
# Processed: 18.jpg -> [Standard] Clean Image
# Processed: 166.jpg -> [Standard] Clean Image
# Processed: 149.jpg -> [Standard] Clean Image
# Processed: 183.jpg -> [Standard] Clean Image
# Processed: 150.jpg -> [Standard] Clean Image
# Processed: 179.jpg -> [Standard] Clean Image
# Processed: 15.jpg -> [Standard] Clean Image
# Processed: 164.jpg -> [Standard] Clean Image
# Processed: 144.jpg -> [Standard] Clean Image
# Processed: 151.jpg -> [Standard] Clean Image
# Processed: 169.jpg -> [Standard] Clean Image
# Processed: 178.jpg -> [Standard] Clean Image
# Processed: 180.jpg -> [Standard] Clean Image
# Processed: 146.jpg -> [Standard] Clean Image
# Processed: 174.jpg -> [Standard] Clean Image
# Processed: 162.jpg -> [Standard] Clean Image
# Processed: 176.jpg -> [Standard] Clean Image
# Processed: 139.jpg -> [Standard] Clean Image
# Processed: 185.jpg -> [Standard] Clean Image
# Processed: 145.jpg -> [Standard] Clean Image
# Processed: 17.jpg -> [Standard] Clean Image
# Processed: 171.jpg -> [Standard] Clean Image
# Processed: 154.jpg -> [Standard] Clean Image
# Processed: 184.jpg -> [Standard] Clean Image
# Processed: 216.jpg -> [Standard] Clean Image
# Processed: 204.jpg -> [Standard] Clean Image
# Processed: 225.jpg -> [Standard] Clean Image
# Processed: 215.jpg -> [Standard] Clean Image
# Processed: 235.jpg -> [Standard] Clean Image
# Processed: 199.jpg -> [Standard] Clean Image
# Processed: 188.jpg -> [Standard] Clean Image
# Processed: 205.jpg -> [Standard] Clean Image
# Processed: 237.jpg -> [Standard] Clean Image
# Processed: 196.jpg -> [Standard] Clean Image
# Processed: 230.jpg -> [Standard] Clean Image
# Processed: 208.jpg -> [Standard] Clean Image
# Processed: 190.jpg -> [Standard] Clean Image
# Processed: 20.jpg -> [Standard] Clean Image
# Processed: 236.jpg -> [Standard] Clean Image
# Processed: 214.jpg -> [Standard] Clean Image
# Processed: 200.jpg -> [Standard] Clean Image
# Processed: 212.jpg -> [Standard] Clean Image
# Processed: 228.jpg -> [Standard] Clean Image
# Processed: 187.jpg -> [Standard] Clean Image
# Processed: 221.jpg -> [Standard] Clean Image
# Processed: 239.jpg -> [Standard] Clean Image
# Processed: 238.jpg -> [Standard] Clean Image
# Processed: 23.jpg -> [Standard] Clean Image
# Processed: 189.jpg -> [Standard] Clean Image
# Processed: 223.jpg -> [Standard] Clean Image
# Processed: 194.jpg -> [Standard] Clean Image
# Processed: 186.jpg -> [Standard] Clean Image
# Processed: 241.jpg -> [Standard] Clean Image
# Processed: 210.jpg -> [Standard] Clean Image
# Processed: 226.jpg -> [Standard] Clean Image
# Processed: 195.jpg -> [Standard] Clean Image
# Processed: 203.jpg -> [Standard] Clean Image
# Processed: 19.jpg -> [Standard] Clean Image
# Processed: 219.jpg -> [Standard] Clean Image
# Processed: 240.jpg -> [Standard] Clean Image
# Processed: 227.jpg -> [Standard] Clean Image
# Processed: 191.jpg -> [Standard] Clean Image
# Processed: 233.jpg -> [Standard] Clean Image
# Processed: 217.jpg -> [Standard] Clean Image
# Processed: 218.jpg -> [Standard] Clean Image
# Processed: 231.jpg -> [Standard] Clean Image
# Processed: 213.jpg -> [Standard] Clean Image
# Processed: 229.jpg -> [Standard] Clean Image
# Processed: 234.jpg -> [Standard] Clean Image
# Processed: 211.jpg -> [Standard] Clean Image
# Processed: 192.jpg -> [Standard] Clean Image
# Processed: 198.jpg -> [Standard] Clean Image
# Processed: 220.jpg -> [Standard] Clean Image
# Processed: 22.jpg -> [Standard] Clean Image
# Processed: 21.jpg -> [Standard] Clean Image
# Processed: 207.jpg -> [Standard] Clean Image
# Processed: 197.jpg -> [Standard] Clean Image
# Processed: 193.jpg -> [Standard] Clean Image
# Processed: 201.jpg -> [Standard] Clean Image
# Processed: 202.jpg -> [Standard] Clean Image
# Processed: 232.jpg -> [Standard] Clean Image
# Processed: 206.jpg -> [Standard] Clean Image
# Processed: 224.jpg -> [Standard] Clean Image
# Processed: 209.jpg -> [Standard] Clean Image
# Processed: 222.jpg -> [Standard] Clean Image
# Processed: 268.jpg -> [Standard] Clean Image
# Processed: 250.jpg -> [Standard] Clean Image
# Processed: 299.jpg -> [Standard] Clean Image
# Processed: 278.jpg -> [Standard] Clean Image
# Processed: 25.jpg -> [Standard] Clean Image
# Processed: 276.jpg -> [Standard] Clean Image
# Processed: 255.jpg -> [Standard] Clean Image
# Processed: 297.jpg -> [Standard] Clean Image
# Processed: 270.jpg -> [Standard] Clean Image
# Processed: 24.jpg -> [Standard] Clean Image
# Processed: 274.jpg -> [Standard] Clean Image
# Processed: 251.jpg -> [Standard] Clean Image
# Processed: 272.jpg -> [Standard] Clean Image
# Processed: 275.jpg -> [Standard] Clean Image
# Processed: 247.jpg -> [Standard] Clean Image
# Processed: 273.jpg -> [Standard] Clean Image
# Processed: 249.jpg -> [Standard] Clean Image
# Processed: 298.jpg -> [Standard] Clean Image
# Processed: 289.jpg -> [Standard] Clean Image
# Processed: 296.jpg -> [Standard] Clean Image
# Processed: 257.jpg -> [Standard] Clean Image
# Processed: 248.jpg -> [Standard] Clean Image
# Processed: 287.jpg -> [Standard] Clean Image
# Processed: 266.jpg -> [Standard] Clean Image
# Processed: 245.jpg -> [Standard] Clean Image
# Processed: 279.jpg -> [Standard] Clean Image
# Processed: 264.jpg -> [Standard] Clean Image
# Processed: 27.jpg -> [Standard] Clean Image
# Processed: 253.jpg -> [Standard] Clean Image
# Processed: 282.jpg -> [Standard] Clean Image
# Processed: 242.jpg -> [Standard] Clean Image
# Processed: 280.jpg -> [Standard] Clean Image
# Processed: 300.jpg -> [Standard] Clean Image
# Processed: 263.jpg -> [Standard] Clean Image
# Processed: 277.jpg -> [Standard] Clean Image
# Processed: 244.jpg -> [Standard] Clean Image
# Processed: 262.jpg -> [Standard] Clean Image
# Processed: 295.jpg -> [Standard] Clean Image
# Processed: 26.jpg -> [Standard] Clean Image
# Processed: 256.jpg -> [Standard] Clean Image
# Processed: 267.jpg -> [Standard] Clean Image
# Processed: 286.jpg -> [Standard] Clean Image
# Processed: 246.jpg -> [Standard] Clean Image
# Processed: 292.jpg -> [Standard] Clean Image
# Processed: 259.jpg -> [Standard] Clean Image
# Processed: 283.jpg -> [Standard] Clean Image
# Processed: 290.jpg -> [Standard] Clean Image
# Processed: 285.jpg -> [Standard] Clean Image
# Processed: 271.jpg -> [Standard] Clean Image
# Processed: 269.jpg -> [Standard] Clean Image
# Processed: 243.jpg -> [Standard] Clean Image
# Processed: 3.jpg -> [Standard] Clean Image
# Processed: 281.jpg -> [Standard] Clean Image
# Processed: 261.jpg -> [Standard] Clean Image
# Processed: 260.jpg -> [Standard] Clean Image
# Processed: 294.jpg -> [Standard] Clean Image
# Processed: 265.jpg -> [Standard] Clean Image
# Processed: 258.jpg -> [Standard] Clean Image
# Processed: 252.jpg -> [Standard] Clean Image
# Processed: 291.jpg -> [Standard] Clean Image
# Processed: 284.jpg -> [Standard] Clean Image
# Processed: 288.jpg -> [Standard] Clean Image
# Processed: 293.jpg -> [Standard] Clean Image
# Processed: 254.jpg -> [Standard] Clean Image
# Processed: 303.jpg -> [Standard] Clean Image
# Processed: 302.jpg -> [Standard] Clean Image
# Processed: 301.jpg -> [Standard] Clean Image
# Processed: 305.jpg -> [Standard] Clean Image
# Processed: 306.jpg -> [Standard] Clean Image
# Processed: 304.jpg -> [Standard] Clean Image
# Processed: 28.jpg -> [Standard] Clean Image
# Processed: 307.jpg -> [Standard] Clean Image
#
# Done, processed 681 images.
# Output: /content/drive/MyDrive/Phase2_Results/Subset_AC
# Running on: /content/drive/MyDrive/AOLP_Dataset/Subset_LE/Image
# Processed: 12.jpg -> [Standard] Clean Image
# Processed: 96.jpg -> [Restormer] Blurry (152)
# Processed: 99.jpg -> [Standard] Clean Image
# Processed: 92.jpg -> [Standard] Clean Image
# Processed: 100.jpg -> [Standard] Clean Image
# Processed: 101.jpg -> [Standard] Clean Image
# Processed: 91.jpg -> [Standard] Clean Image
# Processed: 11.jpg -> [Standard] Clean Image
# Processed: 97.jpg -> [Restormer] Blurry (170)
# Processed: 93.jpg -> [Standard] Clean Image
# Processed: 95.jpg -> [Standard] Clean Image
# Processed: 98.jpg -> [Restormer] Blurry (180)
# Processed: 10.jpg -> [Standard] Clean Image
# Processed: 94.jpg -> [Standard] Clean Image
# Processed: 22.jpg -> [Standard] Clean Image
# Processed: 25.jpg -> [Standard] Clean Image
# Processed: 2.jpg -> [Standard] Clean Image
# Processed: 1.jpg -> [Standard] Clean Image
# Processed: 16.jpg -> [Standard] Clean Image
# Processed: 27.jpg -> [Standard] Clean Image
# Processed: 26.jpg -> [Standard] Clean Image
# Processed: 21.jpg -> [Standard] Clean Image
# Processed: 20.jpg -> [Standard] Clean Image
# Processed: 28.jpg -> [Standard] Clean Image
# Processed: 14.jpg -> [Standard] Clean Image
# Processed: 19.jpg -> [Standard] Clean Image
# Processed: 15.jpg -> [Standard] Clean Image
# Processed: 23.jpg -> [Standard] Clean Image
# Processed: 17.jpg -> [Standard] Clean Image
# Processed: 13.jpg -> [Standard] Clean Image
# Processed: 24.jpg -> [Standard] Clean Image
# Processed: 18.jpg -> [Standard] Clean Image
# Processed: 33.jpg -> [Standard] Clean Image
# Processed: 31.jpg -> [Restormer] Blurry (175)
# Processed: 35.jpg -> [Standard] Clean Image
# Processed: 36.jpg -> [Standard] Clean Image
# Processed: 38.jpg -> [Standard] Clean Image
# Processed: 42.jpg -> [Standard] Clean Image
# Processed: 43.jpg -> [Standard] Clean Image
# Processed: 41.jpg -> [Standard] Clean Image
# Processed: 30.jpg -> [Standard] Clean Image
# Processed: 37.jpg -> [Standard] Clean Image
# Processed: 40.jpg -> [Standard] Clean Image
# Processed: 29.jpg -> [Standard] Clean Image
# Processed: 34.jpg -> [Restormer] Blurry (171)
# Processed: 39.jpg -> [Standard] Clean Image
# Processed: 32.jpg -> [Standard] Clean Image
# Processed: 3.jpg -> [Standard] Clean Image
# Processed: 4.jpg -> [Standard] Clean Image
# Processed: 55.jpg -> [Restormer] Blurry (103)
# Processed: 52.jpg -> [Standard] Clean Image
# Processed: 57.jpg -> [Standard] Clean Image
# Processed: 6.jpg -> [Standard] Clean Image
# Processed: 56.jpg -> [Standard] Clean Image
# Processed: 46.jpg -> [Standard] Clean Image
# Processed: 44.jpg -> [Standard] Clean Image
# Processed: 50.jpg -> [Standard] Clean Image
# Processed: 54.jpg -> [Standard] Clean Image
# Processed: 53.jpg -> [Restormer] Blurry (106)
# Processed: 47.jpg -> [Standard] Clean Image
# Processed: 58.jpg -> [Standard] Clean Image
# Processed: 48.jpg -> [Standard] Clean Image
# Processed: 45.jpg -> [Standard] Clean Image
# Processed: 51.jpg -> [Standard] Clean Image
# Processed: 5.jpg -> [Standard] Clean Image
# Processed: 49.jpg -> [Standard] Clean Image
# Processed: 74.jpg -> [Standard] Clean Image
# Processed: 8.jpg -> [Standard] Clean Image
# Processed: 7.jpg -> [Standard] Clean Image
# Processed: 68.jpg -> [Standard] Clean Image
# Processed: 63.jpg -> [Standard] Clean Image
# Processed: 66.jpg -> [Standard] Clean Image
# Processed: 61.jpg -> [Standard] Clean Image
# Processed: 64.jpg -> [Standard] Clean Image
# Processed: 59.jpg -> [Standard] Clean Image
# Processed: 62.jpg -> [Standard] Clean Image
# Processed: 70.jpg -> [Standard] Clean Image
# Processed: 71.jpg -> [Standard] Clean Image
# Processed: 60.jpg -> [Standard] Clean Image
# Processed: 69.jpg -> [Standard] Clean Image
# Processed: 73.jpg -> [Standard] Clean Image
# Processed: 67.jpg -> [Standard] Clean Image
# Processed: 65.jpg -> [Standard] Clean Image
# Processed: 72.jpg -> [Standard] Clean Image
# Processed: 81.jpg -> [Standard] Clean Image
# Processed: 79.jpg -> [Standard] Clean Image
# Processed: 90.jpg -> [Standard] Clean Image
# Processed: 77.jpg -> [Standard] Clean Image
# Processed: 9.jpg -> [Standard] Clean Image
# Processed: 85.jpg -> [Standard] Clean Image
# Processed: 82.jpg -> [Standard] Clean Image
# Processed: 86.jpg -> [Standard] Clean Image
# Processed: 78.jpg -> [Standard] Clean Image
# Processed: 80.jpg -> [Standard] Clean Image
# Processed: 75.jpg -> [Standard] Clean Image
# Processed: 87.jpg -> [Standard] Clean Image
# Processed: 83.jpg -> [Standard] Clean Image
# Processed: 84.jpg -> [Restormer] Blurry (83)
# Processed: 89.jpg -> [Standard] Clean Image
# Processed: 76.jpg -> [Standard] Clean Image
# Processed: 88.jpg -> [Standard] Clean Image
# Processed: 102.jpg -> [Standard] Clean Image
# Processed: 110.jpg -> [Standard] Clean Image
# Processed: 104.jpg -> [Standard] Clean Image
# Processed: 103.jpg -> [Standard] Clean Image
# Processed: 112.jpg -> [Standard] Clean Image
# Processed: 111.jpg -> [Standard] Clean Image
# Processed: 108.jpg -> [Standard] Clean Image
# Processed: 107.jpg -> [Standard] Clean Image
# Processed: 109.jpg -> [Standard] Clean Image
# Processed: 106.jpg -> [Standard] Clean Image
# Processed: 105.jpg -> [Standard] Clean Image
# Processed: 117.jpg -> [Standard] Clean Image
# Processed: 123.jpg -> [Standard] Clean Image
# Processed: 122.jpg -> [Standard] Clean Image
# Processed: 116.jpg -> [Standard] Clean Image
# Processed: 125.jpg -> [Standard] Clean Image
# Processed: 115.jpg -> [Standard] Clean Image
# Processed: 121.jpg -> [Standard] Clean Image
# Processed: 126.jpg -> [Standard] Clean Image
# Processed: 118.jpg -> [Standard] Clean Image
# Processed: 114.jpg -> [Standard] Clean Image
# Processed: 119.jpg -> [Standard] Clean Image
# Processed: 120.jpg -> [Standard] Clean Image
# Processed: 129.jpg -> [Standard] Clean Image
# Processed: 127.jpg -> [Standard] Clean Image
# Processed: 113.jpg -> [Standard] Clean Image
# Processed: 128.jpg -> [Standard] Clean Image
# Processed: 124.jpg -> [Standard] Clean Image
# Processed: 131.jpg -> [Standard] Clean Image
# Processed: 136.jpg -> [Standard] Clean Image
# Processed: 141.jpg -> [Standard] Clean Image
# Processed: 134.jpg -> [Restormer] Blurry (176)
# Processed: 140.jpg -> [Standard] Clean Image
# Processed: 138.jpg -> [Standard] Clean Image
# Processed: 147.jpg -> [Standard] Clean Image
# Processed: 145.jpg -> [Standard] Clean Image
# Processed: 146.jpg -> [Standard] Clean Image
# Processed: 137.jpg -> [Standard] Clean Image
# Processed: 143.jpg -> [Standard] Clean Image
# Processed: 144.jpg -> [Standard] Clean Image
# Processed: 133.jpg -> [Standard] Clean Image
# Processed: 139.jpg -> [Standard] Clean Image
# Processed: 132.jpg -> [Standard] Clean Image
# Processed: 130.jpg -> [Standard] Clean Image
# Processed: 135.jpg -> [Standard] Clean Image
# Processed: 142.jpg -> [Standard] Clean Image
# Processed: 153.jpg -> [Standard] Clean Image
# Processed: 156.jpg -> [Standard] Clean Image
# Processed: 158.jpg -> [Standard] Clean Image
# Processed: 163.jpg -> [Standard] Clean Image
# Processed: 155.jpg -> [Standard] Clean Image
# Processed: 152.jpg -> [Standard] Clean Image
# Processed: 149.jpg -> [Standard] Clean Image
# Processed: 157.jpg -> [Standard] Clean Image
# Processed: 150.jpg -> [Standard] Clean Image
# Processed: 148.jpg -> [Standard] Clean Image
# Processed: 154.jpg -> [Standard] Clean Image
# Processed: 160.jpg -> [CLAHE] Night Spots (0.0102)
# Processed: 151.jpg -> [Standard] Clean Image
# Processed: 162.jpg -> [Standard] Clean Image
# Processed: 159.jpg -> [Standard] Clean Image
# Processed: 164.jpg -> [Standard] Clean Image
# Processed: 161.jpg -> [Restormer] Blurry (164)
# Processed: 171.jpg -> [Standard] Clean Image
# Processed: 175.jpg -> [Standard] Clean Image
# Processed: 165.jpg -> [Standard] Clean Image
# Processed: 172.jpg -> [Standard] Clean Image
# Processed: 167.jpg -> [Standard] Clean Image
# Processed: 169.jpg -> [Standard] Clean Image
# Processed: 170.jpg -> [Standard] Clean Image
# Processed: 168.jpg -> [Standard] Clean Image
# Processed: 173.jpg -> [Standard] Clean Image
# Processed: 176.jpg -> [Standard] Clean Image
# Processed: 177.jpg -> [Standard] Clean Image
# Processed: 166.jpg -> [Standard] Clean Image
# Processed: 174.jpg -> [Standard] Clean Image
# Processed: 179.jpg -> [Standard] Clean Image
# Processed: 182.jpg -> [Standard] Clean Image
# Processed: 190.jpg -> [Standard] Clean Image
# Processed: 180.jpg -> [Standard] Clean Image
# Processed: 185.jpg -> [Standard] Clean Image
# Processed: 188.jpg -> [Standard] Clean Image
# Processed: 178.jpg -> [Standard] Clean Image
# Processed: 181.jpg -> [Standard] Clean Image
# Processed: 183.jpg -> [Standard] Clean Image
# Processed: 187.jpg -> [Standard] Clean Image
# Processed: 189.jpg -> [Standard] Clean Image
# Processed: 186.jpg -> [Standard] Clean Image
# Processed: 184.jpg -> [Restormer] Blurry (169)
# Processed: 195.jpg -> [Standard] Clean Image
# Processed: 202.jpg -> [Standard] Clean Image
# Processed: 193.jpg -> [Standard] Clean Image
# Processed: 197.jpg -> [Standard] Clean Image
# Processed: 191.jpg -> [Standard] Clean Image
# Processed: 194.jpg -> [Standard] Clean Image
# Processed: 204.jpg -> [Standard] Clean Image
# Processed: 205.jpg -> [Standard] Clean Image
# Processed: 198.jpg -> [Standard] Clean Image
# Processed: 200.jpg -> [Standard] Clean Image
# Processed: 203.jpg -> [Standard] Clean Image
# Processed: 206.jpg -> [Standard] Clean Image
# Processed: 196.jpg -> [Standard] Clean Image
# Processed: 201.jpg -> [Standard] Clean Image
# Processed: 192.jpg -> [Standard] Clean Image
# Processed: 199.jpg -> [Standard] Clean Image
# Processed: 215.jpg -> [Standard] Clean Image
# Processed: 218.jpg -> [Standard] Clean Image
# Processed: 213.jpg -> [Standard] Clean Image
# Processed: 208.jpg -> [Standard] Clean Image
# Processed: 217.jpg -> [Standard] Clean Image
# Processed: 207.jpg -> [Standard] Clean Image
# Processed: 210.jpg -> [Standard] Clean Image
# Processed: 216.jpg -> [Standard] Clean Image
# Processed: 209.jpg -> [Standard] Clean Image
# Processed: 211.jpg -> [Standard] Clean Image
# Processed: 214.jpg -> [Standard] Clean Image
# Processed: 221.jpg -> [Standard] Clean Image
# Processed: 219.jpg -> [Standard] Clean Image
# Processed: 212.jpg -> [Standard] Clean Image
# Processed: 220.jpg -> [Standard] Clean Image
# Processed: 222.jpg -> [Standard] Clean Image
# Processed: 227.jpg -> [Standard] Clean Image
# Processed: 228.jpg -> [Standard] Clean Image
# Processed: 226.jpg -> [Standard] Clean Image
# Processed: 225.jpg -> [Standard] Clean Image
# Processed: 224.jpg -> [Standard] Clean Image
# Processed: 223.jpg -> [Standard] Clean Image
# Processed: 229.jpg -> [Standard] Clean Image
# Processed: 231.jpg -> [Standard] Clean Image
# Processed: 237.jpg -> [Standard] Clean Image
# Processed: 230.jpg -> [Standard] Clean Image
# Processed: 234.jpg -> [Standard] Clean Image
# Processed: 242.jpg -> [Standard] Clean Image
# Processed: 240.jpg -> [Standard] Clean Image
# Processed: 244.jpg -> [Standard] Clean Image
# Processed: 236.jpg -> [Standard] Clean Image
# Processed: 238.jpg -> [Standard] Clean Image
# Processed: 241.jpg -> [Standard] Clean Image
# Processed: 233.jpg -> [Standard] Clean Image
# Processed: 239.jpg -> [Standard] Clean Image
# Processed: 232.jpg -> [Standard] Clean Image
# Processed: 235.jpg -> [Standard] Clean Image
# Processed: 243.jpg -> [Standard] Clean Image
# Processed: 259.jpg -> [Standard] Clean Image
# Processed: 245.jpg -> [Standard] Clean Image
# Processed: 246.jpg -> [Standard] Clean Image
# Processed: 253.jpg -> [Standard] Clean Image
# Processed: 251.jpg -> [Standard] Clean Image
# Processed: 255.jpg -> [Standard] Clean Image
# Processed: 254.jpg -> [Standard] Clean Image
# Processed: 256.jpg -> [Standard] Clean Image
# Processed: 247.jpg -> [Standard] Clean Image
# Processed: 258.jpg -> [Standard] Clean Image
# Processed: 257.jpg -> [Standard] Clean Image
# Processed: 252.jpg -> [CLAHE] Night Spots (0.0268)
# Processed: 250.jpg -> [Standard] Clean Image
# Processed: 249.jpg -> [Standard] Clean Image
# Processed: 248.jpg -> [Standard] Clean Image
# Processed: 264.jpg -> [Standard] Clean Image
# Processed: 265.jpg -> [Standard] Clean Image
# Processed: 267.jpg -> [Standard] Clean Image
# Processed: 260.jpg -> [Standard] Clean Image
# Processed: 266.jpg -> [Standard] Clean Image
# Processed: 263.jpg -> [Standard] Clean Image
# Processed: 270.jpg -> [Standard] Clean Image
# Processed: 261.jpg -> [Standard] Clean Image
# Processed: 262.jpg -> [Standard] Clean Image
# Processed: 269.jpg -> [Standard] Clean Image
# Processed: 273.jpg -> [Standard] Clean Image
# Processed: 268.jpg -> [Standard] Clean Image
# Processed: 271.jpg -> [Standard] Clean Image
# Processed: 272.jpg -> [Standard] Clean Image
# Processed: 276.jpg -> [Standard] Clean Image
# Processed: 281.jpg -> [Standard] Clean Image
# Processed: 274.jpg -> [Standard] Clean Image
# Processed: 286.jpg -> [Standard] Clean Image
# Processed: 284.jpg -> [Standard] Clean Image
# Processed: 285.jpg -> [Standard] Clean Image
# Processed: 283.jpg -> [Standard] Clean Image
# Processed: 279.jpg -> [Standard] Clean Image
# Processed: 275.jpg -> [Standard] Clean Image
# Processed: 278.jpg -> [Standard] Clean Image
# Processed: 280.jpg -> [Standard] Clean Image
# Processed: 282.jpg -> [Standard] Clean Image
# Processed: 287.jpg -> [Standard] Clean Image
# Processed: 277.jpg -> [Standard] Clean Image
# Processed: 295.jpg -> [Standard] Clean Image
# Processed: 297.jpg -> [Standard] Clean Image
# Processed: 294.jpg -> [Standard] Clean Image
# Processed: 293.jpg -> [Standard] Clean Image
# Processed: 291.jpg -> [Standard] Clean Image
# Processed: 289.jpg -> [Standard] Clean Image
# Processed: 292.jpg -> [Standard] Clean Image
# Processed: 290.jpg -> [Standard] Clean Image
# Processed: 296.jpg -> [Standard] Clean Image
# Processed: 288.jpg -> [Standard] Clean Image
# Processed: 305.jpg -> [Standard] Clean Image
# Processed: 302.jpg -> [Standard] Clean Image
# Processed: 304.jpg -> [Standard] Clean Image
# Processed: 299.jpg -> [Standard] Clean Image
# Processed: 298.jpg -> [CLAHE] Too Dark (35.8)
# Processed: 300.jpg -> [Standard] Clean Image
# Processed: 301.jpg -> [Standard] Clean Image
# Processed: 303.jpg -> [Standard] Clean Image
# Processed: 307.jpg -> [Standard] Clean Image
# Processed: 310.jpg -> [Standard] Clean Image
# Processed: 314.jpg -> [Standard] Clean Image
# Processed: 315.jpg -> [Standard] Clean Image
# Processed: 323.jpg -> [Standard] Clean Image
# Processed: 321.jpg -> [Restormer] Blurry (79)
# Processed: 306.jpg -> [Standard] Clean Image
# Processed: 316.jpg -> [Restormer] Blurry (168)
# Processed: 312.jpg -> [Standard] Clean Image
# Processed: 317.jpg -> [Standard] Clean Image
# Processed: 309.jpg -> [Standard] Clean Image
# Processed: 313.jpg -> [Standard] Clean Image
# Processed: 318.jpg -> [Standard] Clean Image
# Processed: 324.jpg -> [Standard] Clean Image
# Processed: 311.jpg -> [Standard] Clean Image
# Processed: 308.jpg -> [Standard] Clean Image
# Processed: 319.jpg -> [Standard] Clean Image
# Processed: 322.jpg -> [Standard] Clean Image
# Processed: 320.jpg -> [Standard] Clean Image
# Processed: 334.jpg -> [Standard] Clean Image
# Processed: 339.jpg -> [Restormer] Blurry (112)
# Processed: 341.jpg -> [Standard] Clean Image
# Processed: 325.jpg -> [Standard] Clean Image
# Processed: 337.jpg -> [Restormer] Blurry (164)
# Processed: 338.jpg -> [Standard] Clean Image
# Processed: 335.jpg -> [Restormer] Blurry (138)
# Processed: 340.jpg -> [Restormer] Blurry (131)
# Processed: 328.jpg -> [Standard] Clean Image
# Processed: 333.jpg -> [Restormer] Blurry (59)
# Processed: 336.jpg -> [Standard] Clean Image
# Processed: 330.jpg -> [Standard] Clean Image
# Processed: 326.jpg -> [Standard] Clean Image
# Processed: 329.jpg -> [Standard] Clean Image
# Processed: 327.jpg -> [Standard] Clean Image
# Processed: 332.jpg -> [Standard] Clean Image
# Processed: 331.jpg -> [CLAHE] Too Dark (37.2)
# Processed: 359.jpg -> [Restormer] Blurry (131)
# Processed: 344.jpg -> [Standard] Clean Image
# Processed: 345.jpg -> [Standard] Clean Image
# Processed: 360.jpg -> [Standard] Clean Image
# Processed: 346.jpg -> [Standard] Clean Image
# Processed: 355.jpg -> [Standard] Clean Image
# Processed: 347.jpg -> [Standard] Clean Image
# Processed: 356.jpg -> [Restormer] Blurry (110)
# Processed: 354.jpg -> [Standard] Clean Image
# Processed: 342.jpg -> [Standard] Clean Image
# Processed: 350.jpg -> [Standard] Clean Image
# Processed: 358.jpg -> [Standard] Clean Image
# Processed: 351.jpg -> [Restormer] Blurry (157)
# Processed: 349.jpg -> [Restormer] Blurry (70)
# Processed: 357.jpg -> [Standard] Clean Image
# Processed: 353.jpg -> [Standard] Clean Image
# Processed: 352.jpg -> [Standard] Clean Image
# Processed: 343.jpg -> [Standard] Clean Image
# Processed: 348.jpg -> [Standard] Clean Image
# Processed: 375.jpg -> [Restormer] Blurry (123)
# Processed: 367.jpg -> [Standard] Clean Image
# ...
# Processed: 283.jpg -> [Standard] Clean Image
# Processed: 281.jpg -> [Standard] Clean Image
# Processed: 271.jpg -> [Standard] Clean Image
# Processed: 318.jpg -> [Standard] Clean Image
# Processed: 270.jpg -> [Standard] Clean Image
# Processed: 313.jpg -> [Standard] Clean Image
# Processed: 288.jpg -> [Standard] Clean Image
# Processed: 261.jpg -> [Standard] Clean Image
# Processed: 311.jpg -> [Standard] Clean Image
# Processed: 287.jpg -> [Standard] Clean Image
# Processed: 316.jpg -> [Standard] Clean Image
# Processed: 319.jpg -> [Standard] Clean Image
# Processed: 273.jpg -> [Standard] Clean Image
# Processed: 265.jpg -> [Standard] Clean Image
# Processed: 285.jpg -> [Standard] Clean Image
# Processed: 296.jpg -> [Standard] Clean Image
# Processed: 306.jpg -> [Standard] Clean Image
# Processed: 267.jpg -> [Standard] Clean Image
# Processed: 290.jpg -> [Standard] Clean Image
# Processed: 284.jpg -> [Standard] Clean Image
# Processed: 305.jpg -> [Standard] Clean Image
# Processed: 266.jpg -> [Standard] Clean Image
# Processed: 314.jpg -> [Standard] Clean Image
# Processed: 269.jpg -> [Standard] Clean Image
# Processed: 297.jpg -> [Standard] Clean Image
# Processed: 315.jpg -> [Standard] Clean Image
# Processed: 320.jpg -> [Standard] Clean Image
# Processed: 278.jpg -> [Standard] Clean Image
# Processed: 312.jpg -> [Standard] Clean Image
# Processed: 274.jpg -> [CLAHE] Night Spots (0.0075)
# Processed: 277.jpg -> [Standard] Clean Image
# Processed: 279.jpg -> [CLAHE] Extreme Contrast/Glare (2648)
# Processed: 268.jpg -> [Standard] Clean Image
# Processed: 317.jpg -> [Standard] Clean Image
# Processed: 309.jpg -> [Standard] Clean Image
# Processed: 307.jpg -> [Standard] Clean Image
# Processed: 282.jpg -> [Standard] Clean Image
# Processed: 295.jpg -> [Standard] Clean Image
# Processed: 302.jpg -> [Standard] Clean Image
# Processed: 304.jpg -> [Standard] Clean Image
# Processed: 292.jpg -> [Standard] Clean Image
# Processed: 272.jpg -> [Standard] Clean Image
# Processed: 264.jpg -> [CLAHE] Too Dark (34.2)
# Processed: 298.jpg -> [Standard] Clean Image
# Processed: 300.jpg -> [Standard] Clean Image
# Processed: 299.jpg -> [Standard] Clean Image
# Processed: 276.jpg -> [Standard] Clean Image
# Processed: 293.jpg -> [Standard] Clean Image
# Processed: 308.jpg -> [Standard] Clean Image
# Processed: 301.jpg -> [Standard] Clean Image
# Processed: 262.jpg -> [Standard] Clean Image
# Processed: 291.jpg -> [Standard] Clean Image
# Processed: 303.jpg -> [CLAHE] Extreme Contrast/Glare (2956)
# Processed: 321.jpg -> [Standard] Clean Image
# Processed: 286.jpg -> [Standard] Clean Image
# Processed: 289.jpg -> [CLAHE] Extreme Contrast/Glare (2725)
# Processed: 263.jpg -> [Standard] Clean Image
# Processed: 280.jpg -> [Standard] Clean Image
# Processed: 294.jpg -> [Standard] Clean Image
# Processed: 334.jpg -> [Standard] Clean Image
# Processed: 342.jpg -> [Standard] Clean Image
# Processed: 366.jpg -> [Standard] Clean Image
# Processed: 330.jpg -> [CLAHE] Extreme Contrast/Glare (2777)
# Processed: 348.jpg -> [Standard] Clean Image
# Processed: 364.jpg -> [Standard] Clean Image
# Processed: 379.jpg -> [Standard] Clean Image
# Processed: 328.jpg -> [Standard] Clean Image
# Processed: 341.jpg -> [Standard] Clean Image
# Processed: 344.jpg -> [Standard] Clean Image
# Processed: 331.jpg -> [CLAHE] Extreme Contrast/Glare (2785)
# Processed: 361.jpg -> [Standard] Clean Image
# Processed: 360.jpg -> [Standard] Clean Image
# Processed: 347.jpg -> [CLAHE] Extreme Contrast/Glare (2451)
# Processed: 345.jpg -> [Standard] Clean Image
# Processed: 359.jpg -> [Standard] Clean Image
# Processed: 381.jpg -> [Standard] Clean Image
# Processed: 370.jpg -> [Standard] Clean Image
# Processed: 362.jpg -> [Standard] Clean Image
# Processed: 351.jpg -> [Standard] Clean Image
# Processed: 372.jpg -> [Standard] Clean Image
# Processed: 374.jpg -> [Standard] Clean Image
# Processed: 353.jpg -> [Standard] Clean Image
# Processed: 358.jpg -> [Standard] Clean Image
# Processed: 368.jpg -> [Standard] Clean Image
# Processed: 337.jpg -> [Standard] Clean Image
# Processed: 343.jpg -> [CLAHE] Extreme Contrast/Glare (2497)
# Processed: 323.jpg -> [Standard] Clean Image
# Processed: 350.jpg -> [Standard] Clean Image
# Processed: 367.jpg -> [Standard] Clean Image
# Processed: 335.jpg -> [Standard] Clean Image
# Processed: 333.jpg -> [Standard] Clean Image
# Processed: 355.jpg -> [CLAHE] Too Dark (37.9)
# Processed: 380.jpg -> [Standard] Clean Image
# Processed: 340.jpg -> [Standard] Clean Image
# Processed: 371.jpg -> [Standard] Clean Image
# Processed: 346.jpg -> [Standard] Clean Image
# Processed: 326.jpg -> [Standard] Clean Image
# Processed: 356.jpg -> [Standard] Clean Image
# Processed: 325.jpg -> [Standard] Clean Image
# Processed: 373.jpg -> [Standard] Clean Image
# Processed: 322.jpg -> [Standard] Clean Image
# Processed: 352.jpg -> [Standard] Clean Image
# Processed: 338.jpg -> [Standard] Clean Image
# Processed: 363.jpg -> [Standard] Clean Image
# Processed: 349.jpg -> [Standard] Clean Image
# Processed: 332.jpg -> [Standard] Clean Image
# Processed: 354.jpg -> [Standard] Clean Image
# Processed: 369.jpg -> [Standard] Clean Image
# Processed: 378.jpg -> [Standard] Clean Image
# Processed: 365.jpg -> [Standard] Clean Image
# Processed: 357.jpg -> [Standard] Clean Image
# Processed: 376.jpg -> [Standard] Clean Image
# Processed: 329.jpg -> [Standard] Clean Image
# Processed: 339.jpg -> [Standard] Clean Image
# Processed: 324.jpg -> [Standard] Clean Image
# Processed: 336.jpg -> [Standard] Clean Image
# Processed: 377.jpg -> [Standard] Clean Image
# Processed: 375.jpg -> [Standard] Clean Image
# Processed: 327.jpg -> [Standard] Clean Image
# Processed: 428.jpg -> [Standard] Clean Image
# Processed: 418.jpg -> [Standard] Clean Image
# Processed: 388.jpg -> [Standard] Clean Image
# Processed: 417.jpg -> [Standard] Clean Image
# Processed: 385.jpg -> [Standard] Clean Image
# Processed: 394.jpg -> [Standard] Clean Image
# Processed: 383.jpg -> [Standard] Clean Image
# Processed: 386.jpg -> [Standard] Clean Image
# Processed: 396.jpg -> [Standard] Clean Image
# Processed: 411.jpg -> [CLAHE] Too Dark (28.3)
# Processed: 430.jpg -> [Standard] Clean Image
# Processed: 415.jpg -> [Standard] Clean Image
# Processed: 387.jpg -> [Standard] Clean Image
# Processed: 432.jpg -> [Standard] Clean Image
# Processed: 407.jpg -> [Standard] Clean Image
# Processed: 390.jpg -> [Standard] Clean Image
# Processed: 412.jpg -> [Standard] Clean Image
# Processed: 393.jpg -> [Standard] Clean Image
# Processed: 403.jpg -> [Standard] Clean Image
# Processed: 413.jpg -> [Standard] Clean Image
# Processed: 405.jpg -> [CLAHE] Too Dark (33.3)
# Processed: 420.jpg -> [Standard] Clean Image
# Processed: 408.jpg -> [Standard] Clean Image
# Processed: 382.jpg -> [Standard] Clean Image
# Processed: 422.jpg -> [Standard] Clean Image
# Processed: 406.jpg -> [Standard] Clean Image
# Processed: 391.jpg -> [Standard] Clean Image
# Processed: 401.jpg -> [Standard] Clean Image
# Processed: 389.jpg -> [Standard] Clean Image
# Processed: 409.jpg -> [Standard] Clean Image
# Processed: 426.jpg -> [Standard] Clean Image
# Processed: 423.jpg -> [Standard] Clean Image
# Processed: 431.jpg -> [Standard] Clean Image
# Processed: 433.jpg -> [Standard] Clean Image
# Processed: 419.jpg -> [Standard] Clean Image
# Processed: 435.jpg -> [Standard] Clean Image
# Processed: 414.jpg -> [Standard] Clean Image
# Processed: 424.jpg -> [Standard] Clean Image
# Processed: 402.jpg -> [Standard] Clean Image
# Processed: 427.jpg -> [Standard] Clean Image
# Processed: 404.jpg -> [Standard] Clean Image
# Processed: 392.jpg -> [Standard] Clean Image
# Processed: 421.jpg -> [Standard] Clean Image
# Processed: 400.jpg -> [Standard] Clean Image
# Processed: 410.jpg -> [Standard] Clean Image
# Processed: 384.jpg -> [Standard] Clean Image
# Processed: 397.jpg -> [Standard] Clean Image
# Processed: 398.jpg -> [Standard] Clean Image
# Processed: 395.jpg -> [CLAHE] Too Dark (39.3)
# Processed: 416.jpg -> [Standard] Clean Image
# Processed: 434.jpg -> [Standard] Clean Image
# Processed: 429.jpg -> [Standard] Clean Image
# Processed: 425.jpg -> [Standard] Clean Image
# Processed: 436.jpg -> [Standard] Clean Image
# Processed: 399.jpg -> [Standard] Clean Image
# Processed: 437.jpg -> [Standard] Clean Image
# Processed: 438.jpg -> [Standard] Clean Image
# Processed: 476.jpg -> [Standard] Clean Image
# Processed: 478.jpg -> [Standard] Clean Image
# Processed: 454.jpg -> [Standard] Clean Image
# Processed: 460.jpg -> [Standard] Clean Image
# Processed: 470.jpg -> [Standard] Clean Image
# Processed: 474.jpg -> [Standard] Clean Image
# Processed: 463.jpg -> [Standard] Clean Image
# Processed: 486.jpg -> [Standard] Clean Image
# Processed: 456.jpg -> [Standard] Clean Image
# Processed: 484.jpg -> [Standard] Clean Image
# Processed: 458.jpg -> [Standard] Clean Image
# Processed: 481.jpg -> [Standard] Clean Image
# Processed: 464.jpg -> [Standard] Clean Image
# Processed: 451.jpg -> [Standard] Clean Image
# Processed: 483.jpg -> [Standard] Clean Image
# Processed: 477.jpg -> [Standard] Clean Image
# Processed: 462.jpg -> [Standard] Clean Image
# Processed: 466.jpg -> [Standard] Clean Image
# Processed: 479.jpg -> [Standard] Clean Image
# Processed: 455.jpg -> [Standard] Clean Image
# Processed: 439.jpg -> [CLAHE] Extreme Contrast/Glare (2985)
# Processed: 446.jpg -> [CLAHE] Extreme Contrast/Glare (2716)
# Processed: 453.jpg -> [Standard] Clean Image
# Processed: 480.jpg -> [Standard] Clean Image
# Processed: 448.jpg -> [Standard] Clean Image
# Processed: 442.jpg -> [Standard] Clean Image
# Processed: 467.jpg -> [Standard] Clean Image
# Processed: 487.jpg -> [Standard] Clean Image
# Processed: 447.jpg -> [CLAHE] Extreme Contrast/Glare (2646)
# Processed: 441.jpg -> [Standard] Clean Image
# Processed: 468.jpg -> [Standard] Clean Image
# Processed: 482.jpg -> [Standard] Clean Image
# Processed: 485.jpg -> [Standard] Clean Image
# Processed: 475.jpg -> [Standard] Clean Image
# Processed: 459.jpg -> [Standard] Clean Image
# Processed: 457.jpg -> [Standard] Clean Image
# Processed: 461.jpg -> [Standard] Clean Image
# Processed: 449.jpg -> [Standard] Clean Image
# Processed: 452.jpg -> [Standard] Clean Image
# Processed: 473.jpg -> [CLAHE] Extreme Contrast/Glare (2572)
# Processed: 472.jpg -> [Standard] Clean Image
# Processed: 488.jpg -> [Standard] Clean Image
# Processed: 443.jpg -> [Standard] Clean Image
# Processed: 450.jpg -> [Standard] Clean Image
# Processed: 469.jpg -> [Standard] Clean Image
# Processed: 440.jpg -> [Standard] Clean Image
# Processed: 444.jpg -> [Standard] Clean Image
# Processed: 465.jpg -> [Standard] Clean Image
# Processed: 489.jpg -> [Standard] Clean Image
# Processed: 471.jpg -> [Standard] Clean Image
# Processed: 445.jpg -> [Standard] Clean Image
# Processed: 520.jpg -> [Standard] Clean Image
# Processed: 492.jpg -> [Standard] Clean Image
# Processed: 505.jpg -> [Standard] Clean Image
# Processed: 541.jpg -> [Standard] Clean Image
# Processed: 517.jpg -> [Standard] Clean Image
# Processed: 501.jpg -> [Standard] Clean Image
# Processed: 491.jpg -> [Standard] Clean Image
# Processed: 514.jpg -> [Standard] Clean Image
# Processed: 516.jpg -> [Standard] Clean Image
# Processed: 528.jpg -> [Standard] Clean Image
# Processed: 522.jpg -> [Standard] Clean Image
# Processed: 500.jpg -> [Standard] Clean Image
# Processed: 525.jpg -> [Standard] Clean Image
# Processed: 508.jpg -> [Standard] Clean Image
# Processed: 521.jpg -> [Standard] Clean Image
# Processed: 542.jpg -> [Standard] Clean Image
# Processed: 504.jpg -> [Standard] Clean Image
# Processed: 540.jpg -> [Standard] Clean Image
# Processed: 497.jpg -> [Standard] Clean Image
# Processed: 544.jpg -> [Standard] Clean Image
# Processed: 502.jpg -> [Standard] Clean Image
# Processed: 509.jpg -> [Standard] Clean Image
# Processed: 519.jpg -> [Standard] Clean Image
# Processed: 510.jpg -> [Standard] Clean Image
# Processed: 543.jpg -> [Standard] Clean Image
# Processed: 511.jpg -> [Standard] Clean Image
# Processed: 507.jpg -> [Standard] Clean Image
# Processed: 530.jpg -> [Standard] Clean Image
# Processed: 527.jpg -> [Standard] Clean Image
# Processed: 535.jpg -> [Standard] Clean Image
# Processed: 513.jpg -> [Standard] Clean Image
# Processed: 538.jpg -> [Standard] Clean Image
# Processed: 495.jpg -> [Standard] Clean Image
# Processed: 531.jpg -> [Standard] Clean Image
# Processed: 526.jpg -> [Standard] Clean Image
# Processed: 496.jpg -> [Standard] Clean Image
# Processed: 494.jpg -> [Standard] Clean Image
# Processed: 533.jpg -> [Standard] Clean Image
# Processed: 524.jpg -> [Standard] Clean Image
# Processed: 532.jpg -> [Standard] Clean Image
# Processed: 523.jpg -> [CLAHE] Extreme Contrast/Glare (2662)
# Processed: 537.jpg -> [Standard] Clean Image
# Processed: 493.jpg -> [Standard] Clean Image
# Processed: 536.jpg -> [Standard] Clean Image
# Processed: 529.jpg -> [Standard] Clean Image
# Processed: 499.jpg -> [Standard] Clean Image
# Processed: 506.jpg -> [Standard] Clean Image
# Processed: 534.jpg -> [Standard] Clean Image
# Processed: 503.jpg -> [Standard] Clean Image
# Processed: 518.jpg -> [Standard] Clean Image
# Processed: 515.jpg -> [Standard] Clean Image
# Processed: 512.jpg -> [Standard] Clean Image
# Processed: 539.jpg -> [Standard] Clean Image
# Processed: 490.jpg -> [Standard] Clean Image
# Processed: 498.jpg -> [Standard] Clean Image
# Processed: 553.jpg -> [Standard] Clean Image
# Processed: 585.jpg -> [Standard] Clean Image
# Processed: 550.jpg -> [Standard] Clean Image
# Processed: 589.jpg -> [Standard] Clean Image
# Processed: 563.jpg -> [Standard] Clean Image
# Processed: 552.jpg -> [Standard] Clean Image
# Processed: 576.jpg -> [Standard] Clean Image
# Processed: 557.jpg -> [Standard] Clean Image
# Processed: 577.jpg -> [Standard] Clean Image
# Processed: 554.jpg -> [Standard] Clean Image
# Processed: 586.jpg -> [Standard] Clean Image
# Processed: 555.jpg -> [Standard] Clean Image
# Processed: 561.jpg -> [Standard] Clean Image
# Processed: 560.jpg -> [Standard] Clean Image
# Processed: 549.jpg -> [Standard] Clean Image
# Processed: 583.jpg -> [Standard] Clean Image
# Processed: 565.jpg -> [CLAHE] Extreme Contrast/Glare (2416)
# Processed: 588.jpg -> [Standard] Clean Image
# Processed: 566.jpg -> [Standard] Clean Image
# Processed: 584.jpg -> [Standard] Clean Image
# Processed: 582.jpg -> [Standard] Clean Image
# Processed: 572.jpg -> [Standard] Clean Image
# Processed: 558.jpg -> [Standard] Clean Image
# Processed: 545.jpg -> [Standard] Clean Image
# Processed: 547.jpg -> [Standard] Clean Image
# Processed: 556.jpg -> [Standard] Clean Image
# Processed: 562.jpg -> [Standard] Clean Image
# Processed: 559.jpg -> [Standard] Clean Image
# Processed: 578.jpg -> [Standard] Clean Image
# Processed: 568.jpg -> [Standard] Clean Image
# Processed: 564.jpg -> [Standard] Clean Image
# Processed: 587.jpg -> [Standard] Clean Image
# Processed: 573.jpg -> [Standard] Clean Image
# Processed: 570.jpg -> [Standard] Clean Image
# Processed: 575.jpg -> [Standard] Clean Image
# Processed: 581.jpg -> [Standard] Clean Image
# Processed: 548.jpg -> [Standard] Clean Image
# Processed: 571.jpg -> [Standard] Clean Image
# Processed: 567.jpg -> [Standard] Clean Image
# Processed: 579.jpg -> [Standard] Clean Image
# Processed: 569.jpg -> [Standard] Clean Image
# Processed: 590.jpg -> [Standard] Clean Image
# Processed: 580.jpg -> [Standard] Clean Image
# Processed: 551.jpg -> [Standard] Clean Image
# Processed: 546.jpg -> [Standard] Clean Image
# Processed: 574.jpg -> [Standard] Clean Image
# Processed: 609.jpg -> [Standard] Clean Image
# Processed: 610.jpg -> [Standard] Clean Image
# Processed: 607.jpg -> [Standard] Clean Image
# Processed: 606.jpg -> [Standard] Clean Image
# Processed: 597.jpg -> [Standard] Clean Image
# Processed: 602.jpg -> [Standard] Clean Image
# Processed: 611.jpg -> [Standard] Clean Image
# Processed: 608.jpg -> [Standard] Clean Image
# Processed: 600.jpg -> [Standard] Clean Image
# Processed: 605.jpg -> [Standard] Clean Image
# Processed: 595.jpg -> [Standard] Clean Image
# Processed: 599.jpg -> [Standard] Clean Image
# Processed: 596.jpg -> [Standard] Clean Image
# Processed: 603.jpg -> [Standard] Clean Image
# Processed: 604.jpg -> [Standard] Clean Image
# Processed: 601.jpg -> [Standard] Clean Image
# Processed: 591.jpg -> [Standard] Clean Image
# Processed: 598.jpg -> [Standard] Clean Image
# Processed: 593.jpg -> [Standard] Clean Image
# Processed: 592.jpg -> [Standard] Clean Image
# Processed: 594.jpg -> [Standard] Clean Image
#
# Done, processed 611 images.
# Output: /content/drive/MyDrive/Phase2_Results/Subset_RP
